# %%
import pandas as pd

# %%
df = pd.read_csv('BTC_sum_both_10m_v202303271051_1.csv')
df.shape
df.head()

# %%
for col in df.columns:
    print(col)
# Out:
# window_start
# window_end
# realized_volatility_mean0
# realized_up_volatility_mean0
# realized_down_volatility_mean0
# num_trades
# lowest_return
# highest_return
# high_low_gap
# trade_vol
# volume_power
# end_price
# return
# time_id
# log_return_temp
# BB_width_w20
# BB_width_w40
# BB_width_w10
# dv5_realized_volatility_mean0
# dv2_lowest_return
# dv3_highest_return
# window_end_150_ticker
# realized_volatility_mean0_150
# num_trades_150
# lowest_return_150
# highest_return_150
# high_low_gap_150
# trade_vol_150
# volume_power_150
# window_end_300_ticker
# realized_volatility_mean0_300
# num_trades_300
# lowest_return_300
# highest_return_300
# high_low_gap_300
# trade_vol_300
# volume_power_300
# window_end_450_ticker
# realized_volatility_mean0_450
# num_trades_450
# lowest_return_450
# highest_return_450
# high_low_gap_450
# trade_vol_450
# volume_power_450
# liq_last_1
# liq_last_2
# liq_last_5
# liq_last_10
# liq_last_15
# ep_liq_1
# ep_liq_2
# ep_liq_5
# ep_liq_10
# ...

# %%
# 컬럼 이름을 입력할 데이터프레임 생성
col_df = pd.DataFrame()

col_df['컬럼이름'] = df.columns

col_df
# Out:
#                                컬럼이름
# 0                      window_start
# 1                        window_end
# 2         realized_volatility_mean0
# 3      realized_up_volatility_mean0
# 4    realized_down_volatility_mean0
# ..                              ...
# 108                        tvpl_ep1
# 109                        tvpl_ep2
# 110                        tvpl_ep5
# 111                       tvpl_ep10
# 112                       tvpl_ep15
#
# [113 rows x 1 columns]

# %%
#col_df.to_excel('컬럼명.xlsx', index=False)

# %%
df.head()
# Out:
#           window_start           window_end  realized_volatility_mean0  \
# 0  2022-12-16 21:06:00  2022-12-16 21:16:00                   0.000544
# 1  2022-12-16 21:07:00  2022-12-16 21:17:00                   0.000208
# 2  2022-12-16 21:08:00  2022-12-16 21:18:00                   0.000216
# 3  2022-12-16 21:09:00  2022-12-16 21:19:00                   0.000292
# 4  2022-12-16 21:10:00  2022-12-16 21:20:00                   0.000394
#
#    realized_up_volatility_mean0  realized_down_volatility_mean0  num_trades  \
# 0                      0.000079                        0.000563         394
# 1                      0.000225                        0.000195         398
# 2                      0.000281                        0.000130         373
# 3                      0.000320                        0.000044         349
# 4                      0.000000                        0.000414         357
#
#    lowest_return  highest_return  high_low_gap  trade_vol  ...         tvpl1  \
# ...

# %%
df['time_id'].head()
# Out:
# 0    2022-12-16 21:06:00
# 1    2022-12-16 21:07:00
# 2    2022-12-16 21:08:00
# 3    2022-12-16 21:09:00
# 4    2022-12-16 21:10:00
# Name: time_id, dtype: object

# %%
raw_df = pd.read_csv('ticker_data_202302230905.csv', nrows=100)

# %%
raw_df
# Out:
#    type_websocket                 datetime      code  opening_price  \
# 0       orderbook  2023-01-21 20:33:43.000   KRW-BTC            NaN
# 1       orderbook  2023-01-21 20:33:43.000  KRW-DOGE            NaN
# 2       orderbook  2023-01-21 20:33:43.000   KRW-BTC            NaN
# 3       orderbook  2023-01-21 20:33:43.000   KRW-XRP            NaN
# 4       orderbook  2023-01-21 20:33:44.000   KRW-XRP            NaN
# ..            ...                      ...       ...            ...
# 95          trade  2023-01-21 20:33:49.000   KRW-BTC            NaN
# 96         ticker  2023-01-21 20:33:49.000   KRW-BTC     28025000.0
# 97      orderbook  2023-01-21 20:33:49.000   KRW-XRP            NaN
# 98      orderbook  2023-01-21 20:33:49.000   KRW-BTC            NaN
# 99      orderbook  2023-01-21 20:33:49.000   KRW-ETH            NaN
#
#     high_price   low_price  trade_price  prev_closing_price change  \
# 0          NaN         NaN          NaN                 NaN    NaN
# ...

# %%
raw_df['type_websocket'].unique()
# Out:
# array(['orderbook', 'trade', 'ticker'], dtype=object)

# %%
raw_df.to_csv('bitcoin_sample.csv')
