# %% [markdown]
# AIX30009 Fall 2024
#
# **_Copyright Notice_**
#
# This notebook is available for educational purposes. You may not use or distribute this notebook for commercial purposes. You may make copies of this notebook and use or distribute it for educational purposes as long as you cite the author as the source of the notebook.
#
# Jaeyoung Chun | School of Applied Artificial Intelligence | Handong Global University

# %% [markdown]
# # Fashion MNIST FIB (Fill in the Blank) Version

# %% [markdown]
# Replace ??? with proper values.

# %%
import torch
from torch import nn
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.5.0+cu121'

# %%
# %config InlineBackend.figure_format='retina'

# %%
# set the random seed
torch.manual_seed(316)

# %% [markdown]
# # Load Data

# %%
# convert to tensor
# data augumentation -> 성능 개선을 위해 추가한 방법
# normalize the data

transform = transforms.Compose([
    transforms.ToTensor(),                               # 먼저 Tensor로 변환
    transforms.RandomCrop(32, padding=4),                # 무작위 위치에서 자르기
    transforms.RandomHorizontalFlip(),                   # 좌우 반전
    transforms.RandomRotation(degrees=[0, 45]),          # 무작위 회전
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 색상 변화
    transforms.RandomErasing(p=0.9, scale=(0.03, 0.03)), # 랜덤 지우기
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),  # 정규화
])

# %% [markdown]
# ## Download

# %%
# download the dataset
dataset = datasets.CIFAR100('.', download=True, train=True, transform=transform)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## Split

# %%
# split
len_trainset = int(len(dataset) * 0.8)
len_valset = len(dataset) - len_trainset

trainset, valset = torch.utils.data.random_split(dataset, [len_trainset, len_valset])

# %%
len(trainset)
# Out:
# 40000

# %%
len(valset)
# Out:
# 10000

# %% [markdown]
# ## Training Set

# %%
# loader for the training set
batch_size = 64
trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# ## Validation Set

# %%
# loader for the validatoin set
valloader = torch.utils.data.DataLoader(
    valset,
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# # Explore Data

# %%
idx_to_class = { v:k for k, v in trainset.dataset.class_to_idx.items() }
idx_to_class
# Out:
# {0: 'apple',
#  1: 'aquarium_fish',
#  2: 'baby',
#  3: 'bear',
#  4: 'beaver',
#  5: 'bed',
#  6: 'bee',
#  7: 'beetle',
#  8: 'bicycle',
#  9: 'bottle',
#  10: 'bowl',
#  11: 'boy',
#  12: 'bridge',
#  13: 'bus',
#  14: 'butterfly',
#  15: 'camel',
#  16: 'can',
#  17: 'castle',
#  18: 'caterpillar',
#  19: 'cattle',
#  20: 'chair',
#  21: 'chimpanzee',
#  22: 'clock',
#  23: 'cloud',
#  24: 'cockroach',
#  25: 'couch',
#  26: 'crab',
#  27: 'crocodile',
#  28: 'cup',
#  29: 'dinosaur',
#  30: 'dolphin',
#  31: 'elephant',
#  32: 'flatfish',
#  33: 'forest',
#  34: 'fox',
#  35: 'girl',
#  36: 'hamster',
#  37: 'house',
#  38: 'kangaroo',
#  39: 'keyboard',
#  40: 'lamp',
#  41: 'lawn_mower',
#  42: 'leopard',
#  43: 'lion',
#  44: 'lizard',
#  45: 'lobster',
#  46: 'man',
#  47: 'maple_tree',
#  48: 'motorcycle',
#  49: 'mountain',
#  50: 'mouse',
#  51: 'mushroom',
#  52: 'oak_tree',
#  53: 'orange',
#  54: 'orchid',
#  55: 'otter',
#  56: 'palm_tree',
#  57: 'pear',
#  58: 'pickup_truck',
#  59: 'pine_tree',
#  60: 'plain',
#  61: 'plate',
#  62: 'poppy',
#  63: 'porcupine',
#  64: 'possum',
#  65: 'rabbit',
#  66: 'raccoon',
#  67: 'ray',
#  68: 'road',
#  69: 'rocket',
#  70: 'rose',
#  71: 'sea',
#  72: 'seal',
#  73: 'shark',
#  74: 'shrew',
#  75: 'skunk',
#  76: 'skyscraper',
#  77: 'snail',
#  78: 'snake',
#  79: 'spider',
#  80: 'squirrel',
#  81: 'streetcar',
#  82: 'sunflower',
#  83: 'sweet_pepper',
#  84: 'table',
#  85: 'tank',
#  86: 'telephone',
#  87: 'television',
#  88: 'tiger',
#  89: 'tractor',
#  90: 'train',
#  91: 'trout',
#  92: 'tulip',
#  93: 'turtle',
#  94: 'wardrobe',
#  95: 'whale',
#  96: 'willow_tree',
#  97: 'wolf',
#  98: 'woman',
#  99: 'worm'}

# %%
# get a first batch
images, labels = next(iter(trainloader))

# %%
images.shape
# Out:
# torch.Size([64, 3, 32, 32])

# %%
fig, ax = plt.subplots(figsize=(3,3))

img_idx = 0
label = idx_to_class[int(labels[0])] # color img

ax.imshow(images[0][0])
ax.set_title(f"Label: {label}")

plt.show()

# %%
fig, ax = plt.subplots(ncols=5, nrows=3, figsize=(12,6))
ax = np.ravel(ax)

for index in range(15):
    ax[index].imshow(images[index][0]) # color img
    label = idx_to_class[int(labels[index])]
    ax[index].set_title(f"Label: {label}")
    ax[index].set_xticks([])
    ax[index].set_yticks([])

plt.show()

# %% [markdown]
# # Build Neural Network

# %%
from collections import OrderedDict
import torch.nn.functional as F

## 성능 개선을 위해 모델을 기존보다 더욱 복잡하게 설계

class Network(nn.Module):
    def __init__(self):
        super().__init__()

        self.feature_extraction = nn.Sequential(
            OrderedDict([
                ("conv1", nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)),
                ("bn1", nn.BatchNorm2d(64)),
                ("relu1", nn.ReLU()),
                ("pool1", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv2", nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)),
                ("bn2", nn.BatchNorm2d(128)),
                ("relu2", nn.ReLU()),
                ("pool2", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv3", nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)),
                ("bn3", nn.BatchNorm2d(256)),
                ("relu3", nn.ReLU()),
                ("pool3", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv4", nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1)),
                ("bn4", nn.BatchNorm2d(512)),
                ("relu4", nn.ReLU()),
                ("pool4", nn.MaxPool2d(kernel_size=2, stride=2)),
            ])
        )

        self.classifier = nn.Sequential(
            OrderedDict([
                ("fc1", nn.Linear(512 * 2 * 2, 1024)),
                ("relu5", nn.ReLU()),
                ("dropout1", nn.Dropout(0.5)),

                ("fc2", nn.Linear(1024, 512)),
                ("relu6", nn.ReLU()),
                ("dropout2", nn.Dropout(0.5)),

                ("fc3", nn.Linear(512, 128)),
                ("relu7", nn.ReLU()),
                ("dropout3", nn.Dropout(0.5)),

                ("fc4", nn.Linear(128, 100))
            ])
        )

    def forward(self, x):
        out1 = self.feature_extraction(x)
        out2 = torch.flatten(out1, 1)
        out3 = self.classifier(out2)
        return out3

# 모델 인스턴스 생성 및 출력
model = Network()
print(model)
# Out:
# Network(
#   (feature_extraction): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU()
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU()
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (relu5): ReLU()
#     (dropout1): Dropout(p=0.5, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu6): ReLU()
#     (dropout2): Dropout(p=0.5, inplace=False)
#     (fc3): Linear(in_features=512, out_features=128, bias=True)
#     (relu7): ReLU()
#     (dropout3): Dropout(p=0.5, inplace=False)
#     (fc4): Linear(in_features=128, out_features=100, bias=True)
#   )
# )

# %%
total_params = 0
for name, param in model.named_parameters():
    print(name, param.shape, param.numel())
    total_params += param.numel()

print(f"Total number of parameters = {total_params}")
# Out:
# feature_extraction.conv1.weight torch.Size([64, 3, 3, 3]) 1728
# feature_extraction.conv1.bias torch.Size([64]) 64
# feature_extraction.bn1.weight torch.Size([64]) 64
# feature_extraction.bn1.bias torch.Size([64]) 64
# feature_extraction.conv2.weight torch.Size([128, 64, 3, 3]) 73728
# feature_extraction.conv2.bias torch.Size([128]) 128
# feature_extraction.bn2.weight torch.Size([128]) 128
# feature_extraction.bn2.bias torch.Size([128]) 128
# feature_extraction.conv3.weight torch.Size([256, 128, 3, 3]) 294912
# feature_extraction.conv3.bias torch.Size([256]) 256
# feature_extraction.bn3.weight torch.Size([256]) 256
# feature_extraction.bn3.bias torch.Size([256]) 256
# feature_extraction.conv4.weight torch.Size([512, 256, 3, 3]) 1179648
# feature_extraction.conv4.bias torch.Size([512]) 512
# feature_extraction.bn4.weight torch.Size([512]) 512
# feature_extraction.bn4.bias torch.Size([512]) 512
# classifier.fc1.weight torch.Size([1024, 2048]) 2097152
# classifier.fc1.bias torch.Size([1024]) 1024
# classifier.fc2.weight torch.Size([512, 1024]) 524288
# classifier.fc2.bias torch.Size([512]) 512
# classifier.fc3.weight torch.Size([128, 512]) 65536
# classifier.fc3.bias torch.Size([128]) 128
# classifier.fc4.weight torch.Size([100, 128]) 12800
# classifier.fc4.bias torch.Size([100]) 100
# Total number of parameters = 4254436

# %%
from torchinfo import summary

summary(model, input_size=(batch_size, 3, 32, 32), device="cpu")
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Network                                  [64, 100]                 --
# ├─Sequential: 1-1                        [64, 512, 2, 2]           --
# │    └─Conv2d: 2-1                       [64, 64, 32, 32]          1,792
# │    └─BatchNorm2d: 2-2                  [64, 64, 32, 32]          128
# │    └─ReLU: 2-3                         [64, 64, 32, 32]          --
# │    └─MaxPool2d: 2-4                    [64, 64, 16, 16]          --
# │    └─Conv2d: 2-5                       [64, 128, 16, 16]         73,856
# │    └─BatchNorm2d: 2-6                  [64, 128, 16, 16]         256
# │    └─ReLU: 2-7                         [64, 128, 16, 16]         --
# │    └─MaxPool2d: 2-8                    [64, 128, 8, 8]           --
# │    └─Conv2d: 2-9                       [64, 256, 8, 8]           295,168
# │    └─BatchNorm2d: 2-10                 [64, 256, 8, 8]           512
# │    └─ReLU: 2-11                        [64, 256, 8, 8]           --
# │    └─MaxPool2d: 2-12                   [64, 256, 4, 4]           --
# │    └─Conv2d: 2-13                      [64, 512, 4, 4]           1,180,160
# │    └─BatchNorm2d: 2-14                 [64, 512, 4, 4]           1,024
# │    └─ReLU: 2-15                        [64, 512, 4, 4]           --
# │    └─MaxPool2d: 2-16                   [64, 512, 2, 2]           --
# ├─Sequential: 1-2                        [64, 100]                 --
# │    └─Linear: 2-17                      [64, 1024]                2,098,176
# │    └─ReLU: 2-18                        [64, 1024]                --
# │    └─Dropout: 2-19                     [64, 1024]                --
# │    └─Linear: 2-20                      [64, 512]                 524,800
# │    └─ReLU: 2-21                        [64, 512]                 --
# │    └─Dropout: 2-22                     [64, 512]                 --
# │    └─Linear: 2-23                      [64, 128]                 65,664
# │    └─ReLU: 2-24                        [64, 128]                 --
# │    └─Dropout: 2-25                     [64, 128]                 --
# │    └─Linear: 2-26                      [64, 100]                 12,900
# ==========================================================================================
# Total params: 4,254,436
# Trainable params: 4,254,436
# Non-trainable params: 0
# Total mult-adds (G): 3.92
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 126.73
# Params size (MB): 17.02
# Estimated Total Size (MB): 144.54
# ==========================================================================================

# %% [markdown]
# # Training and Validation

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
if torch.cuda.is_available():
    print(torch.cuda.current_device())
# Out:
# 0

# %%
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA A100-SXM4-40GB

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model.to(device)
# Out:
# Network(
#   (feature_extraction): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU()
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU()
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (relu5): ReLU()
#     (dropout1): Dropout(p=0.5, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu6): ReLU()
#     (dropout2): Dropout(p=0.5, inplace=False)
#     (fc3): Linear(in_features=512, out_features=128, bias=True)
#     (relu7): ReLU()
#     (dropout3): Dropout(p=0.5, inplace=False)
#     (fc4): Linear(in_features=128, out_features=100, bias=True)
#   )
# )

# %%
import time

# %%
from torch import optim

# 성능 개선을 위해 L2 norm + optimizer: Adam + lr_scheduler 설정.

weight_decay = 0.001  # L2 정규화 적용
learning_rate = 0.001

# 옵티마이저 설정
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay, betas=(0.9, 0.999), eps=1e-08)

# learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# define the loss
criterion = nn.CrossEntropyLoss()

# %%
start_time = time.time()

n_epochs = 200

train_loss_history = []
val_loss_history = []
accuracy_history = []

for epoch in range(n_epochs):

    train_loss = 0

    model.train()

    for images, labels in trainloader:

        images, labels = images.to(device), labels.to(device)

        # zero the gradients on each training pass
        optimizer.zero_grad()

        # make a forward pass through the network
        logits = model.forward(images)

        # use the network output to calculate the loss (output vs. ground truth)
        loss = criterion(logits, labels)

        # make a backward pass through the network to calculate the gradients (backpropagation)
        loss.backward()

        # update the weights
        optimizer.step()

        # keep track of the loss per epoch
        train_loss += loss.item()

    else:

        train_loss = train_loss / len(trainloader)
        train_loss_history.append(train_loss)

        val_loss = 0
        accuracy = 0

        with torch.no_grad():

            model.eval()

            for images, labels in valloader:

                images, labels = images.to(device), labels.to(device)

                logits = model.forward(images)

                loss = criterion(logits, labels)

                val_loss += loss.item()

                probabilities = logits.softmax(dim=1)

                top_probs, top_classes = probabilities.topk(k=1, dim=1)
                corrects = (top_classes == labels.view(*top_classes.shape))
                accuracy += torch.mean(corrects.type(torch.FloatTensor))

        val_loss = val_loss / len(valloader)
        val_loss_history.append(val_loss)

        accuracy = accuracy / len(valloader)
        accuracy_history.append(accuracy)

        metrics = f"Epoch: {epoch + 1:02}/{n_epochs:02}"
        metrics += " | "
        metrics += f"Train loss: {train_loss:.3f}"
        metrics += " | "
        metrics += f"Validation loss: {val_loss:.3f}"
        metrics += " | "
        metrics += f"Accuracy: {accuracy:.3f}"
        print(metrics)

        # 스케줄러 업데이트
        scheduler.step()  # 학습률 감소

print("Elapsed: {0:.2f} seconds".format(time.time() - start_time))
# Out:
# Epoch: 01/200 | Train loss: 4.497 | Validation loss: 4.376 | Accuracy: 0.025
# Epoch: 02/200 | Train loss: 4.354 | Validation loss: 4.264 | Accuracy: 0.032
# Epoch: 03/200 | Train loss: 4.277 | Validation loss: 4.324 | Accuracy: 0.038
# Epoch: 04/200 | Train loss: 4.201 | Validation loss: 4.102 | Accuracy: 0.050
# Epoch: 05/200 | Train loss: 4.097 | Validation loss: 3.953 | Accuracy: 0.078
# Epoch: 06/200 | Train loss: 4.007 | Validation loss: 3.899 | Accuracy: 0.084
# Epoch: 07/200 | Train loss: 3.933 | Validation loss: 3.782 | Accuracy: 0.094
# Epoch: 08/200 | Train loss: 3.865 | Validation loss: 3.745 | Accuracy: 0.100
# Epoch: 09/200 | Train loss: 3.809 | Validation loss: 3.675 | Accuracy: 0.120
# Epoch: 10/200 | Train loss: 3.776 | Validation loss: 3.632 | Accuracy: 0.120
# Epoch: 11/200 | Train loss: 3.680 | Validation loss: 3.559 | Accuracy: 0.135
# Epoch: 12/200 | Train loss: 3.635 | Validation loss: 3.470 | Accuracy: 0.151
# Epoch: 13/200 | Train loss: 3.593 | Validation loss: 3.446 | Accuracy: 0.155
# Epoch: 14/200 | Train loss: 3.558 | Validation loss: 3.389 | Accuracy: 0.162
# Epoch: 15/200 | Train loss: 3.523 | Validation loss: 3.394 | Accuracy: 0.167
# Epoch: 16/200 | Train loss: 3.493 | Validation loss: 3.333 | Accuracy: 0.174
# Epoch: 17/200 | Train loss: 3.459 | Validation loss: 3.280 | Accuracy: 0.187
# Epoch: 18/200 | Train loss: 3.426 | Validation loss: 3.262 | Accuracy: 0.200
# Epoch: 19/200 | Train loss: 3.392 | Validation loss: 3.231 | Accuracy: 0.198
# Epoch: 20/200 | Train loss: 3.362 | Validation loss: 3.215 | Accuracy: 0.205
# Epoch: 21/200 | Train loss: 3.273 | Validation loss: 3.107 | Accuracy: 0.219
# Epoch: 22/200 | Train loss: 3.246 | Validation loss: 3.083 | Accuracy: 0.228
# Epoch: 23/200 | Train loss: 3.224 | Validation loss: 3.072 | Accuracy: 0.231
# Epoch: 24/200 | Train loss: 3.196 | Validation loss: 3.026 | Accuracy: 0.234
# Epoch: 25/200 | Train loss: 3.175 | Validation loss: 3.035 | Accuracy: 0.239
# Epoch: 26/200 | Train loss: 3.158 | Validation loss: 2.979 | Accuracy: 0.246
# Epoch: 27/200 | Train loss: 3.134 | Validation loss: 2.984 | Accuracy: 0.251
# Epoch: 28/200 | Train loss: 3.116 | Validation loss: 2.975 | Accuracy: 0.248
# Epoch: 29/200 | Train loss: 3.099 | Validation loss: 2.940 | Accuracy: 0.252
# Epoch: 30/200 | Train loss: 3.079 | Validation loss: 2.915 | Accuracy: 0.257
# Epoch: 31/200 | Train loss: 3.032 | Validation loss: 2.861 | Accuracy: 0.267
# Epoch: 32/200 | Train loss: 3.010 | Validation loss: 2.853 | Accuracy: 0.268
# Epoch: 33/200 | Train loss: 2.997 | Validation loss: 2.832 | Accuracy: 0.274
# Epoch: 34/200 | Train loss: 2.993 | Validation loss: 2.826 | Accuracy: 0.279
# Epoch: 35/200 | Train loss: 2.982 | Validation loss: 2.805 | Accuracy: 0.282
# Epoch: 36/200 | Train loss: 2.970 | Validation loss: 2.804 | Accuracy: 0.283
# Epoch: 37/200 | Train loss: 2.950 | Validation loss: 2.800 | Accuracy: 0.285
# Epoch: 38/200 | Train loss: 2.942 | Validation loss: 2.815 | Accuracy: 0.284
# Epoch: 39/200 | Train loss: 2.930 | Validation loss: 2.780 | Accuracy: 0.290
# Epoch: 40/200 | Train loss: 2.940 | Validation loss: 2.769 | Accuracy: 0.287
# Epoch: 41/200 | Train loss: 2.896 | Validation loss: 2.750 | Accuracy: 0.294
# Epoch: 42/200 | Train loss: 2.900 | Validation loss: 2.756 | Accuracy: 0.293
# Epoch: 43/200 | Train loss: 2.895 | Validation loss: 2.736 | Accuracy: 0.295
# Epoch: 44/200 | Train loss: 2.886 | Validation loss: 2.741 | Accuracy: 0.294
# Epoch: 45/200 | Train loss: 2.885 | Validation loss: 2.735 | Accuracy: 0.299
# Epoch: 46/200 | Train loss: 2.869 | Validation loss: 2.731 | Accuracy: 0.301
# Epoch: 47/200 | Train loss: 2.868 | Validation loss: 2.740 | Accuracy: 0.299
# Epoch: 48/200 | Train loss: 2.859 | Validation loss: 2.712 | Accuracy: 0.299
# Epoch: 49/200 | Train loss: 2.855 | Validation loss: 2.715 | Accuracy: 0.300
# Epoch: 50/200 | Train loss: 2.847 | Validation loss: 2.713 | Accuracy: 0.298
# Epoch: 51/200 | Train loss: 2.837 | Validation loss: 2.705 | Accuracy: 0.306
# Epoch: 52/200 | Train loss: 2.832 | Validation loss: 2.696 | Accuracy: 0.304
# Epoch: 53/200 | Train loss: 2.836 | Validation loss: 2.695 | Accuracy: 0.310
# Epoch: 54/200 | Train loss: 2.835 | Validation loss: 2.677 | Accuracy: 0.312
# Epoch: 55/200 | Train loss: 2.822 | Validation loss: 2.695 | Accuracy: 0.306
# Epoch: 56/200 | Train loss: 2.822 | Validation loss: 2.674 | Accuracy: 0.308
# Epoch: 57/200 | Train loss: 2.831 | Validation loss: 2.679 | Accuracy: 0.307
# Epoch: 58/200 | Train loss: 2.819 | Validation loss: 2.690 | Accuracy: 0.308
# Epoch: 59/200 | Train loss: 2.816 | Validation loss: 2.682 | Accuracy: 0.300
# Epoch: 60/200 | Train loss: 2.813 | Validation loss: 2.675 | Accuracy: 0.308
# Epoch: 61/200 | Train loss: 2.808 | Validation loss: 2.668 | Accuracy: 0.308
# Epoch: 62/200 | Train loss: 2.809 | Validation loss: 2.675 | Accuracy: 0.307
# Epoch: 63/200 | Train loss: 2.802 | Validation loss: 2.680 | Accuracy: 0.308
# Epoch: 64/200 | Train loss: 2.805 | Validation loss: 2.674 | Accuracy: 0.313
# Epoch: 65/200 | Train loss: 2.801 | Validation loss: 2.663 | Accuracy: 0.312
# Epoch: 66/200 | Train loss: 2.806 | Validation loss: 2.656 | Accuracy: 0.311
# Epoch: 67/200 | Train loss: 2.798 | Validation loss: 2.672 | Accuracy: 0.313
# Epoch: 68/200 | Train loss: 2.795 | Validation loss: 2.668 | Accuracy: 0.314
# Epoch: 69/200 | Train loss: 2.789 | Validation loss: 2.669 | Accuracy: 0.310
# Epoch: 70/200 | Train loss: 2.797 | Validation loss: 2.664 | Accuracy: 0.314
# Epoch: 71/200 | Train loss: 2.792 | Validation loss: 2.658 | Accuracy: 0.312
# Epoch: 72/200 | Train loss: 2.781 | Validation loss: 2.667 | Accuracy: 0.311
# Epoch: 73/200 | Train loss: 2.789 | Validation loss: 2.657 | Accuracy: 0.314
# Epoch: 74/200 | Train loss: 2.790 | Validation loss: 2.655 | Accuracy: 0.316
# Epoch: 75/200 | Train loss: 2.785 | Validation loss: 2.669 | Accuracy: 0.312
# Epoch: 76/200 | Train loss: 2.781 | Validation loss: 2.661 | Accuracy: 0.312
# Epoch: 77/200 | Train loss: 2.790 | Validation loss: 2.661 | Accuracy: 0.313
# Epoch: 78/200 | Train loss: 2.783 | Validation loss: 2.650 | Accuracy: 0.318
# Epoch: 79/200 | Train loss: 2.778 | Validation loss: 2.657 | Accuracy: 0.313
# Epoch: 80/200 | Train loss: 2.779 | Validation loss: 2.651 | Accuracy: 0.313
# Epoch: 81/200 | Train loss: 2.778 | Validation loss: 2.648 | Accuracy: 0.321
# Epoch: 82/200 | Train loss: 2.773 | Validation loss: 2.654 | Accuracy: 0.320
# Epoch: 83/200 | Train loss: 2.778 | Validation loss: 2.653 | Accuracy: 0.314
# Epoch: 84/200 | Train loss: 2.785 | Validation loss: 2.658 | Accuracy: 0.316
# Epoch: 85/200 | Train loss: 2.782 | Validation loss: 2.662 | Accuracy: 0.316
# Epoch: 86/200 | Train loss: 2.773 | Validation loss: 2.649 | Accuracy: 0.314
# Epoch: 87/200 | Train loss: 2.769 | Validation loss: 2.652 | Accuracy: 0.313
# Epoch: 88/200 | Train loss: 2.770 | Validation loss: 2.649 | Accuracy: 0.318
# Epoch: 89/200 | Train loss: 2.774 | Validation loss: 2.658 | Accuracy: 0.309
# Epoch: 90/200 | Train loss: 2.777 | Validation loss: 2.648 | Accuracy: 0.315
# Epoch: 91/200 | Train loss: 2.782 | Validation loss: 2.643 | Accuracy: 0.315
# Epoch: 92/200 | Train loss: 2.776 | Validation loss: 2.653 | Accuracy: 0.318
# Epoch: 93/200 | Train loss: 2.774 | Validation loss: 2.652 | Accuracy: 0.317
# Epoch: 94/200 | Train loss: 2.776 | Validation loss: 2.641 | Accuracy: 0.314
# Epoch: 95/200 | Train loss: 2.770 | Validation loss: 2.662 | Accuracy: 0.315
# Epoch: 96/200 | Train loss: 2.759 | Validation loss: 2.644 | Accuracy: 0.313
# Epoch: 97/200 | Train loss: 2.778 | Validation loss: 2.646 | Accuracy: 0.313
# Epoch: 98/200 | Train loss: 2.767 | Validation loss: 2.646 | Accuracy: 0.314
# Epoch: 99/200 | Train loss: 2.770 | Validation loss: 2.648 | Accuracy: 0.316
# Epoch: 100/200 | Train loss: 2.777 | Validation loss: 2.664 | Accuracy: 0.309
# Epoch: 101/200 | Train loss: 2.772 | Validation loss: 2.645 | Accuracy: 0.325
# Epoch: 102/200 | Train loss: 2.768 | Validation loss: 2.652 | Accuracy: 0.316
# Epoch: 103/200 | Train loss: 2.764 | Validation loss: 2.657 | Accuracy: 0.313
# Epoch: 104/200 | Train loss: 2.780 | Validation loss: 2.635 | Accuracy: 0.320
# Epoch: 105/200 | Train loss: 2.775 | Validation loss: 2.661 | Accuracy: 0.313
# Epoch: 106/200 | Train loss: 2.780 | Validation loss: 2.639 | Accuracy: 0.318
# Epoch: 107/200 | Train loss: 2.774 | Validation loss: 2.638 | Accuracy: 0.315
# Epoch: 108/200 | Train loss: 2.765 | Validation loss: 2.656 | Accuracy: 0.315
# Epoch: 109/200 | Train loss: 2.774 | Validation loss: 2.643 | Accuracy: 0.319
# Epoch: 110/200 | Train loss: 2.774 | Validation loss: 2.660 | Accuracy: 0.311
# Epoch: 111/200 | Train loss: 2.776 | Validation loss: 2.647 | Accuracy: 0.318
# Epoch: 112/200 | Train loss: 2.769 | Validation loss: 2.660 | Accuracy: 0.315
# Epoch: 113/200 | Train loss: 2.769 | Validation loss: 2.633 | Accuracy: 0.319
# Epoch: 114/200 | Train loss: 2.765 | Validation loss: 2.650 | Accuracy: 0.318
# Epoch: 115/200 | Train loss: 2.771 | Validation loss: 2.663 | Accuracy: 0.312
# Epoch: 116/200 | Train loss: 2.766 | Validation loss: 2.642 | Accuracy: 0.319
# Epoch: 117/200 | Train loss: 2.772 | Validation loss: 2.658 | Accuracy: 0.309
# Epoch: 118/200 | Train loss: 2.769 | Validation loss: 2.660 | Accuracy: 0.312
# Epoch: 119/200 | Train loss: 2.773 | Validation loss: 2.651 | Accuracy: 0.313
# Epoch: 120/200 | Train loss: 2.771 | Validation loss: 2.654 | Accuracy: 0.315
# Epoch: 121/200 | Train loss: 2.769 | Validation loss: 2.661 | Accuracy: 0.312
# Epoch: 122/200 | Train loss: 2.773 | Validation loss: 2.639 | Accuracy: 0.320
# Epoch: 123/200 | Train loss: 2.776 | Validation loss: 2.638 | Accuracy: 0.319
# Epoch: 124/200 | Train loss: 2.771 | Validation loss: 2.641 | Accuracy: 0.317
# Epoch: 125/200 | Train loss: 2.765 | Validation loss: 2.630 | Accuracy: 0.317
# Epoch: 126/200 | Train loss: 2.775 | Validation loss: 2.653 | Accuracy: 0.312
# Epoch: 127/200 | Train loss: 2.768 | Validation loss: 2.639 | Accuracy: 0.316
# Epoch: 128/200 | Train loss: 2.774 | Validation loss: 2.662 | Accuracy: 0.312
# Epoch: 129/200 | Train loss: 2.767 | Validation loss: 2.654 | Accuracy: 0.314
# Epoch: 130/200 | Train loss: 2.777 | Validation loss: 2.637 | Accuracy: 0.319
# Epoch: 131/200 | Train loss: 2.769 | Validation loss: 2.646 | Accuracy: 0.317
# Epoch: 132/200 | Train loss: 2.775 | Validation loss: 2.644 | Accuracy: 0.318
# Epoch: 133/200 | Train loss: 2.763 | Validation loss: 2.657 | Accuracy: 0.317
# Epoch: 134/200 | Train loss: 2.768 | Validation loss: 2.648 | Accuracy: 0.314
# Epoch: 135/200 | Train loss: 2.773 | Validation loss: 2.648 | Accuracy: 0.317
# Epoch: 136/200 | Train loss: 2.773 | Validation loss: 2.645 | Accuracy: 0.314
# Epoch: 137/200 | Train loss: 2.767 | Validation loss: 2.657 | Accuracy: 0.313
# Epoch: 138/200 | Train loss: 2.770 | Validation loss: 2.639 | Accuracy: 0.318
# Epoch: 139/200 | Train loss: 2.771 | Validation loss: 2.667 | Accuracy: 0.312
# Epoch: 140/200 | Train loss: 2.774 | Validation loss: 2.664 | Accuracy: 0.310
# Epoch: 141/200 | Train loss: 2.776 | Validation loss: 2.647 | Accuracy: 0.318
# Epoch: 142/200 | Train loss: 2.770 | Validation loss: 2.652 | Accuracy: 0.318
# Epoch: 143/200 | Train loss: 2.771 | Validation loss: 2.636 | Accuracy: 0.317
# Epoch: 144/200 | Train loss: 2.781 | Validation loss: 2.649 | Accuracy: 0.317
# Epoch: 145/200 | Train loss: 2.765 | Validation loss: 2.653 | Accuracy: 0.315
# Epoch: 146/200 | Train loss: 2.781 | Validation loss: 2.643 | Accuracy: 0.319
# Epoch: 147/200 | Train loss: 2.776 | Validation loss: 2.652 | Accuracy: 0.316
# Epoch: 148/200 | Train loss: 2.767 | Validation loss: 2.645 | Accuracy: 0.315
# Epoch: 149/200 | Train loss: 2.773 | Validation loss: 2.646 | Accuracy: 0.315
# Epoch: 150/200 | Train loss: 2.776 | Validation loss: 2.639 | Accuracy: 0.321
# Epoch: 151/200 | Train loss: 2.768 | Validation loss: 2.655 | Accuracy: 0.317
# Epoch: 152/200 | Train loss: 2.771 | Validation loss: 2.643 | Accuracy: 0.321
# Epoch: 153/200 | Train loss: 2.774 | Validation loss: 2.638 | Accuracy: 0.318
# Epoch: 154/200 | Train loss: 2.775 | Validation loss: 2.657 | Accuracy: 0.314
# Epoch: 155/200 | Train loss: 2.770 | Validation loss: 2.639 | Accuracy: 0.321
# Epoch: 156/200 | Train loss: 2.767 | Validation loss: 2.648 | Accuracy: 0.319
# Epoch: 157/200 | Train loss: 2.774 | Validation loss: 2.640 | Accuracy: 0.316
# Epoch: 158/200 | Train loss: 2.780 | Validation loss: 2.653 | Accuracy: 0.314
# Epoch: 159/200 | Train loss: 2.774 | Validation loss: 2.646 | Accuracy: 0.315
# Epoch: 160/200 | Train loss: 2.768 | Validation loss: 2.657 | Accuracy: 0.315
# Epoch: 161/200 | Train loss: 2.777 | Validation loss: 2.643 | Accuracy: 0.315
# Epoch: 162/200 | Train loss: 2.767 | Validation loss: 2.633 | Accuracy: 0.316
# Epoch: 163/200 | Train loss: 2.774 | Validation loss: 2.645 | Accuracy: 0.318
# Epoch: 164/200 | Train loss: 2.775 | Validation loss: 2.638 | Accuracy: 0.319
# Epoch: 165/200 | Train loss: 2.772 | Validation loss: 2.640 | Accuracy: 0.319
# Epoch: 166/200 | Train loss: 2.763 | Validation loss: 2.654 | Accuracy: 0.319
# Epoch: 167/200 | Train loss: 2.773 | Validation loss: 2.663 | Accuracy: 0.311
# Epoch: 168/200 | Train loss: 2.770 | Validation loss: 2.642 | Accuracy: 0.312
# Epoch: 169/200 | Train loss: 2.771 | Validation loss: 2.646 | Accuracy: 0.317
# Epoch: 170/200 | Train loss: 2.763 | Validation loss: 2.638 | Accuracy: 0.319
# Epoch: 171/200 | Train loss: 2.775 | Validation loss: 2.650 | Accuracy: 0.316
# Epoch: 172/200 | Train loss: 2.769 | Validation loss: 2.648 | Accuracy: 0.314
# Epoch: 173/200 | Train loss: 2.783 | Validation loss: 2.648 | Accuracy: 0.315
# Epoch: 174/200 | Train loss: 2.772 | Validation loss: 2.635 | Accuracy: 0.314
# Epoch: 175/200 | Train loss: 2.779 | Validation loss: 2.650 | Accuracy: 0.321
# Epoch: 176/200 | Train loss: 2.776 | Validation loss: 2.637 | Accuracy: 0.317
# Epoch: 177/200 | Train loss: 2.773 | Validation loss: 2.644 | Accuracy: 0.321
# Epoch: 178/200 | Train loss: 2.766 | Validation loss: 2.657 | Accuracy: 0.317
# Epoch: 179/200 | Train loss: 2.773 | Validation loss: 2.638 | Accuracy: 0.323
# Epoch: 180/200 | Train loss: 2.762 | Validation loss: 2.646 | Accuracy: 0.316
# Epoch: 181/200 | Train loss: 2.778 | Validation loss: 2.642 | Accuracy: 0.317
# Epoch: 182/200 | Train loss: 2.772 | Validation loss: 2.647 | Accuracy: 0.319
# Epoch: 183/200 | Train loss: 2.774 | Validation loss: 2.631 | Accuracy: 0.327
# Epoch: 184/200 | Train loss: 2.764 | Validation loss: 2.630 | Accuracy: 0.322
# Epoch: 185/200 | Train loss: 2.766 | Validation loss: 2.638 | Accuracy: 0.317
# Epoch: 186/200 | Train loss: 2.774 | Validation loss: 2.651 | Accuracy: 0.315
# Epoch: 187/200 | Train loss: 2.775 | Validation loss: 2.650 | Accuracy: 0.315
# Epoch: 188/200 | Train loss: 2.760 | Validation loss: 2.649 | Accuracy: 0.315
# Epoch: 189/200 | Train loss: 2.768 | Validation loss: 2.648 | Accuracy: 0.319
# Epoch: 190/200 | Train loss: 2.781 | Validation loss: 2.645 | Accuracy: 0.313
# Epoch: 191/200 | Train loss: 2.773 | Validation loss: 2.651 | Accuracy: 0.317
# Epoch: 192/200 | Train loss: 2.766 | Validation loss: 2.644 | Accuracy: 0.319
# Epoch: 193/200 | Train loss: 2.775 | Validation loss: 2.655 | Accuracy: 0.312
# Epoch: 194/200 | Train loss: 2.773 | Validation loss: 2.644 | Accuracy: 0.316
# Epoch: 195/200 | Train loss: 2.777 | Validation loss: 2.639 | Accuracy: 0.317
# Epoch: 196/200 | Train loss: 2.772 | Validation loss: 2.634 | Accuracy: 0.318
# Epoch: 197/200 | Train loss: 2.767 | Validation loss: 2.646 | Accuracy: 0.319
# Epoch: 198/200 | Train loss: 2.773 | Validation loss: 2.661 | Accuracy: 0.315
# Epoch: 199/200 | Train loss: 2.774 | Validation loss: 2.632 | Accuracy: 0.318
# Epoch: 200/200 | Train loss: 2.778 | Validation loss: 2.653 | Accuracy: 0.322
# Elapsed: 23659.34 seconds

# %% [markdown]
# # Metrics

# %%
fig, ax = plt.subplots(figsize=(6,6))

ax.plot(train_loss_history, label="Train Loss")
ax.plot(val_loss_history, label="Validation Loss")

ax.set_xlabel("epoch")
ax.set_ylabel("loss")
ax.set_title("Train Loss & Validation Loss")
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(accuracy_history, label="Accuracy")

ax.set_xlabel("epoch")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy")

plt.show()

# %%
# download the testset
testset = datasets.CIFAR100('.', download=True, train=False, transform=transform)

# loader for the testset
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=batch_size,
    shuffle=True
)
# Out:
# Files already downloaded and verified

# %%
total = 0
total_corrects = 0
with torch.no_grad():

    for images, labels in testloader:

        images, labels = images.to(device), labels.to(device)

        logits = model.forward(images)

        probabilities = logits.softmax(dim=1)

        top_probs, top_classes = probabilities.topk(k=1, dim=1)
        corrects = (top_classes == labels.view(*top_classes.shape))
        corrects = int(torch.sum(corrects).cpu().numpy())
        total_corrects += corrects

        total += labels.size(0)

# %%
total_corrects / total * 100.0
# Out:
# 32.629999999999995

# %% [markdown]
# ### 성능 개선
#
# 성능을 개선하기 위해 (Accuracy가 최소 50% 이상) 나오게 하기 위하여 여러 방법을 적용하였다.
#
# 1. Data Augumentation
# 2. CNN 모델을 더욱 복잡하고 설계
# 3. 옵티마이저 설정(L2 norm + optimizer: Adam + lr_scheduler)
# 4. 100 epochs를 수행 결과를 보면 overfitting이 발견되지 않았다.
#
# 결과적으로 더 많은 epochs를 수행하면 결국 50% 이상의 accuracy score를 얻을 수 있을 것이다.
