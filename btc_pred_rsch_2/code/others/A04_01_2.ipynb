# %% [markdown]
# AIX30009 Fall 2024
#
# **_Copyright Notice_**
#
# This notebook is available for educational purposes. You may not use or distribute this notebook for commercial purposes. You may make copies of this notebook and use or distribute it for educational purposes as long as you cite the author as the source of the notebook.
#
# Jaeyoung Chun | School of Applied Artificial Intelligence | Handong Global University

# %% [markdown]
# # Fashion MNIST FIB (Fill in the Blank) Version

# %% [markdown]
# Replace ??? with proper values.

# %%
import torch
from torch import nn
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.5.1+cu121'

# %%
# %config InlineBackend.figure_format='retina'

# %%
# set the random seed
torch.manual_seed(316)

# %% [markdown]
# # Load Data

# %%
# convert to tensor
# data augumentation -> 성능 개선을 위해 추가한 방법
# normalize the data

transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.RandomRotation(degrees=[0, 45]),
        transforms.RandomErasing(p=0.9, scale=(0.03, 0.03)),
        transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
    ]
)

# %% [markdown]
# ## Download

# %%
# download the dataset
dataset = datasets.CIFAR100('.', download=True, train=True, transform=transform)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## Split

# %%
# split
len_trainset = int(len(dataset) * 0.8)
len_valset = len(dataset) - len_trainset

trainset, valset = torch.utils.data.random_split(dataset, [len_trainset, len_valset])

# %%
len(trainset)
# Out:
# 40000

# %%
len(valset)
# Out:
# 10000

# %% [markdown]
# ## Training Set

# %%
# loader for the training set
batch_size = 64
trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# ## Validation Set

# %%
# loader for the validatoin set
valloader = torch.utils.data.DataLoader(
    valset,
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# # Explore Data

# %%
idx_to_class = { v:k for k, v in trainset.dataset.class_to_idx.items() }
idx_to_class
# Out:
# {0: 'apple',
#  1: 'aquarium_fish',
#  2: 'baby',
#  3: 'bear',
#  4: 'beaver',
#  5: 'bed',
#  6: 'bee',
#  7: 'beetle',
#  8: 'bicycle',
#  9: 'bottle',
#  10: 'bowl',
#  11: 'boy',
#  12: 'bridge',
#  13: 'bus',
#  14: 'butterfly',
#  15: 'camel',
#  16: 'can',
#  17: 'castle',
#  18: 'caterpillar',
#  19: 'cattle',
#  20: 'chair',
#  21: 'chimpanzee',
#  22: 'clock',
#  23: 'cloud',
#  24: 'cockroach',
#  25: 'couch',
#  26: 'crab',
#  27: 'crocodile',
#  28: 'cup',
#  29: 'dinosaur',
#  30: 'dolphin',
#  31: 'elephant',
#  32: 'flatfish',
#  33: 'forest',
#  34: 'fox',
#  35: 'girl',
#  36: 'hamster',
#  37: 'house',
#  38: 'kangaroo',
#  39: 'keyboard',
#  40: 'lamp',
#  41: 'lawn_mower',
#  42: 'leopard',
#  43: 'lion',
#  44: 'lizard',
#  45: 'lobster',
#  46: 'man',
#  47: 'maple_tree',
#  48: 'motorcycle',
#  49: 'mountain',
#  50: 'mouse',
#  51: 'mushroom',
#  52: 'oak_tree',
#  53: 'orange',
#  54: 'orchid',
#  55: 'otter',
#  56: 'palm_tree',
#  57: 'pear',
#  58: 'pickup_truck',
#  59: 'pine_tree',
#  60: 'plain',
#  61: 'plate',
#  62: 'poppy',
#  63: 'porcupine',
#  64: 'possum',
#  65: 'rabbit',
#  66: 'raccoon',
#  67: 'ray',
#  68: 'road',
#  69: 'rocket',
#  70: 'rose',
#  71: 'sea',
#  72: 'seal',
#  73: 'shark',
#  74: 'shrew',
#  75: 'skunk',
#  76: 'skyscraper',
#  77: 'snail',
#  78: 'snake',
#  79: 'spider',
#  80: 'squirrel',
#  81: 'streetcar',
#  82: 'sunflower',
#  83: 'sweet_pepper',
#  84: 'table',
#  85: 'tank',
#  86: 'telephone',
#  87: 'television',
#  88: 'tiger',
#  89: 'tractor',
#  90: 'train',
#  91: 'trout',
#  92: 'tulip',
#  93: 'turtle',
#  94: 'wardrobe',
#  95: 'whale',
#  96: 'willow_tree',
#  97: 'wolf',
#  98: 'woman',
#  99: 'worm'}

# %%
# get a first batch
images, labels = next(iter(trainloader))

# %%
images.shape
# Out:
# torch.Size([64, 3, 32, 32])

# %%
fig, ax = plt.subplots(figsize=(3,3))

img_idx = 0
label = idx_to_class[int(labels[0])] # color img

ax.imshow(images[0][0])
ax.set_title(f"Label: {label}")

plt.show()

# %%
fig, ax = plt.subplots(ncols=5, nrows=3, figsize=(12,6))
ax = np.ravel(ax)

for index in range(15):
    ax[index].imshow(images[index][0]) # color img
    label = idx_to_class[int(labels[index])]
    ax[index].set_title(f"Label: {label}")
    ax[index].set_xticks([])
    ax[index].set_yticks([])

plt.show()

# %% [markdown]
# # Build Neural Network

# %%
from collections import OrderedDict
import torch
import torch.nn as nn
import torch.nn.functional as F

class Network(nn.Module):
    def __init__(self):
        super().__init__()

        self.feature_extraction = nn.Sequential(
            OrderedDict([
                ("conv1", nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)),
                ("bn1", nn.BatchNorm2d(64)),
                ("relu1", nn.ReLU()),
                ("pool1", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv2", nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)),
                ("bn2", nn.BatchNorm2d(128)),
                ("relu2", nn.ReLU()),
                ("pool2", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv3", nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)),
                ("bn3", nn.BatchNorm2d(256)),
                ("relu3", nn.ReLU()),
                ("pool3", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv4", nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1)),
                ("bn4", nn.BatchNorm2d(512)),
                ("relu4", nn.ReLU()),
                ("pool4", nn.MaxPool2d(kernel_size=2, stride=2)),
            ])
        )

        self.classifier = nn.Sequential(
            OrderedDict([
                ("fc1", nn.Linear(512 * 2 * 2, 1024)),
                ("relu5", nn.ReLU()),
                ("dropout1", nn.Dropout(0.7)),

                ("fc2", nn.Linear(1024, 512)),
                ("relu6", nn.ReLU()),
                ("dropout2", nn.Dropout(0.7)),

                ("fc3", nn.Linear(512, 128)),
                ("relu7", nn.ReLU()),
                ("dropout3", nn.Dropout(0.7)),

                ("fc4", nn.Linear(128, 100))
            ])
        )

        # Weight Initialization
        self._initialize_weights()

    def forward(self, x):
        out1 = self.feature_extraction(x)
        out2 = torch.flatten(out1, 1)
        out3 = self.classifier(out2)
        return out3

    def _initialize_weights(self):
        # Initialize weights for convolutional and linear layers
        for module in self.modules():
            if isinstance(module, nn.Conv2d):
                nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.BatchNorm2d):
                nn.init.constant_(module.weight, 1)
                nn.init.constant_(module.bias, 0)

# 모델 인스턴스 생성 및 출력
model = Network()
print(model)
# Out:
# Network(
#   (feature_extraction): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU()
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU()
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (relu5): ReLU()
#     (dropout1): Dropout(p=0.7, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu6): ReLU()
#     (dropout2): Dropout(p=0.7, inplace=False)
#     (fc3): Linear(in_features=512, out_features=128, bias=True)
#     (relu7): ReLU()
#     (dropout3): Dropout(p=0.7, inplace=False)
#     (fc4): Linear(in_features=128, out_features=100, bias=True)
#   )
# )

# %%
total_params = 0
for name, param in model.named_parameters():
    print(name, param.shape, param.numel())
    total_params += param.numel()

print(f"Total number of parameters = {total_params}")
# Out:
# feature_extraction.conv1.weight torch.Size([64, 3, 3, 3]) 1728
# feature_extraction.conv1.bias torch.Size([64]) 64
# feature_extraction.bn1.weight torch.Size([64]) 64
# feature_extraction.bn1.bias torch.Size([64]) 64
# feature_extraction.conv2.weight torch.Size([128, 64, 3, 3]) 73728
# feature_extraction.conv2.bias torch.Size([128]) 128
# feature_extraction.bn2.weight torch.Size([128]) 128
# feature_extraction.bn2.bias torch.Size([128]) 128
# feature_extraction.conv3.weight torch.Size([256, 128, 3, 3]) 294912
# feature_extraction.conv3.bias torch.Size([256]) 256
# feature_extraction.bn3.weight torch.Size([256]) 256
# feature_extraction.bn3.bias torch.Size([256]) 256
# feature_extraction.conv4.weight torch.Size([512, 256, 3, 3]) 1179648
# feature_extraction.conv4.bias torch.Size([512]) 512
# feature_extraction.bn4.weight torch.Size([512]) 512
# feature_extraction.bn4.bias torch.Size([512]) 512
# classifier.fc1.weight torch.Size([1024, 2048]) 2097152
# classifier.fc1.bias torch.Size([1024]) 1024
# classifier.fc2.weight torch.Size([512, 1024]) 524288
# classifier.fc2.bias torch.Size([512]) 512
# classifier.fc3.weight torch.Size([128, 512]) 65536
# classifier.fc3.bias torch.Size([128]) 128
# classifier.fc4.weight torch.Size([100, 128]) 12800
# classifier.fc4.bias torch.Size([100]) 100
# Total number of parameters = 4254436

# %%
# from torchinfo import summary

# summary(model, input_size=(batch_size, 3, 32, 32), device="cpu")

# %% [markdown]
# # Training and Validation

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
if torch.cuda.is_available():
    print(torch.cuda.current_device())
# Out:
# 0

# %%
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA A100-SXM4-40GB

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model.to(device)
# Out:
# Network(
#   (feature_extraction): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU()
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU()
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (relu5): ReLU()
#     (dropout1): Dropout(p=0.7, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu6): ReLU()
#     (dropout2): Dropout(p=0.7, inplace=False)
#     (fc3): Linear(in_features=512, out_features=128, bias=True)
#     (relu7): ReLU()
#     (dropout3): Dropout(p=0.7, inplace=False)
#     (fc4): Linear(in_features=128, out_features=100, bias=True)
#   )
# )

# %%
import time

# %%
from torch import optim

# 성능 개선을 위해 L2 norm + optimizer: Adam + lr_scheduler 설정.

weight_decay = 0.001  # L2 정규화 적용
learning_rate = 0.001

# 옵티마이저 설정
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay, betas=(0.9, 0.999), eps=1e-08)

# learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

# define the loss
criterion = nn.CrossEntropyLoss()

# %%
start_time = time.time()

n_epochs = 300

train_loss_history = []
val_loss_history = []
accuracy_history = []

for epoch in range(n_epochs):

    train_loss = 0

    model.train()

    for images, labels in trainloader:

        images, labels = images.to(device), labels.to(device)

        # zero the gradients on each training pass
        optimizer.zero_grad()

        # make a forward pass through the network
        logits = model.forward(images)

        # use the network output to calculate the loss (output vs. ground truth)
        loss = criterion(logits, labels)

        # make a backward pass through the network to calculate the gradients (backpropagation)
        loss.backward()

        # update the weights
        optimizer.step()

        # keep track of the loss per epoch
        train_loss += loss.item()

    else:

        train_loss = train_loss / len(trainloader)
        train_loss_history.append(train_loss)

        val_loss = 0
        accuracy = 0

        with torch.no_grad():

            model.eval()

            for images, labels in valloader:

                images, labels = images.to(device), labels.to(device)

                logits = model.forward(images)

                loss = criterion(logits, labels)

                val_loss += loss.item()

                probabilities = logits.softmax(dim=1)

                top_probs, top_classes = probabilities.topk(k=1, dim=1)
                corrects = (top_classes == labels.view(*top_classes.shape))
                accuracy += torch.mean(corrects.type(torch.FloatTensor))

        val_loss = val_loss / len(valloader)
        val_loss_history.append(val_loss)

        accuracy = accuracy / len(valloader)
        accuracy_history.append(accuracy)

        metrics = f"Epoch: {epoch + 1:02}/{n_epochs:02}"
        metrics += " | "
        metrics += f"Train loss: {train_loss:.3f}"
        metrics += " | "
        metrics += f"Validation loss: {val_loss:.3f}"
        metrics += " | "
        metrics += f"Accuracy: {accuracy:.3f}"
        print(metrics)

        # 스케줄러 업데이트
        scheduler.step()  # 학습률 감소

print("Elapsed: {0:.2f} seconds".format(time.time() - start_time))
# Out:
# Epoch: 01/300 | Train loss: 5.901 | Validation loss: 4.606 | Accuracy: 0.009
# Epoch: 02/300 | Train loss: 4.606 | Validation loss: 4.607 | Accuracy: 0.008
# Epoch: 03/300 | Train loss: 4.606 | Validation loss: 4.607 | Accuracy: 0.008
# Epoch: 04/300 | Train loss: 4.606 | Validation loss: 4.607 | Accuracy: 0.009
# Epoch: 05/300 | Train loss: 4.606 | Validation loss: 4.607 | Accuracy: 0.008
# Epoch: 06/300 | Train loss: 4.606 | Validation loss: 4.607 | Accuracy: 0.008
# Epoch: 07/300 | Train loss: 4.606 | Validation loss: 4.607 | Accuracy: 0.008
# Epoch: 08/300 | Train loss: 4.606 | Validation loss: 4.607 | Accuracy: 0.009
# Epoch: 09/300 | Train loss: 4.594 | Validation loss: 4.509 | Accuracy: 0.017
# Epoch: 10/300 | Train loss: 4.501 | Validation loss: 4.508 | Accuracy: 0.018
# Epoch: 11/300 | Train loss: 4.439 | Validation loss: 4.369 | Accuracy: 0.023
# Epoch: 12/300 | Train loss: 4.330 | Validation loss: 4.243 | Accuracy: 0.035
# Epoch: 13/300 | Train loss: 4.247 | Validation loss: 4.149 | Accuracy: 0.043
# Epoch: 14/300 | Train loss: 4.194 | Validation loss: 4.120 | Accuracy: 0.044
# Epoch: 15/300 | Train loss: 4.146 | Validation loss: 4.033 | Accuracy: 0.060
# Epoch: 16/300 | Train loss: 4.051 | Validation loss: 3.912 | Accuracy: 0.066
# Epoch: 17/300 | Train loss: 3.983 | Validation loss: 3.823 | Accuracy: 0.080
# Epoch: 18/300 | Train loss: 3.930 | Validation loss: 3.815 | Accuracy: 0.079
# Epoch: 19/300 | Train loss: 3.874 | Validation loss: 3.738 | Accuracy: 0.092
# Epoch: 20/300 | Train loss: 3.813 | Validation loss: 3.652 | Accuracy: 0.106
# Epoch: 21/300 | Train loss: 3.761 | Validation loss: 3.599 | Accuracy: 0.110
# Epoch: 22/300 | Train loss: 3.690 | Validation loss: 3.461 | Accuracy: 0.131
# Epoch: 23/300 | Train loss: 3.633 | Validation loss: 3.450 | Accuracy: 0.138
# Epoch: 24/300 | Train loss: 3.596 | Validation loss: 3.413 | Accuracy: 0.145
# Epoch: 25/300 | Train loss: 3.561 | Validation loss: 3.360 | Accuracy: 0.156
# Epoch: 26/300 | Train loss: 3.523 | Validation loss: 3.342 | Accuracy: 0.166
# Epoch: 27/300 | Train loss: 3.497 | Validation loss: 3.289 | Accuracy: 0.163
# Epoch: 28/300 | Train loss: 3.466 | Validation loss: 3.328 | Accuracy: 0.161
# Epoch: 29/300 | Train loss: 3.445 | Validation loss: 3.256 | Accuracy: 0.183
# Epoch: 30/300 | Train loss: 3.417 | Validation loss: 3.233 | Accuracy: 0.177
# Epoch: 31/300 | Train loss: 3.404 | Validation loss: 3.201 | Accuracy: 0.189
# Epoch: 32/300 | Train loss: 3.382 | Validation loss: 3.186 | Accuracy: 0.202
# Epoch: 33/300 | Train loss: 3.366 | Validation loss: 3.191 | Accuracy: 0.196
# Epoch: 34/300 | Train loss: 3.335 | Validation loss: 3.137 | Accuracy: 0.210
# Epoch: 35/300 | Train loss: 3.319 | Validation loss: 3.118 | Accuracy: 0.212
# Epoch: 36/300 | Train loss: 3.299 | Validation loss: 3.131 | Accuracy: 0.208
# Epoch: 37/300 | Train loss: 3.276 | Validation loss: 3.109 | Accuracy: 0.210
# Epoch: 38/300 | Train loss: 3.265 | Validation loss: 3.095 | Accuracy: 0.213
# Epoch: 39/300 | Train loss: 3.259 | Validation loss: 3.054 | Accuracy: 0.226
# Epoch: 40/300 | Train loss: 3.240 | Validation loss: 3.061 | Accuracy: 0.224
# Epoch: 41/300 | Train loss: 3.233 | Validation loss: 3.009 | Accuracy: 0.231
# Epoch: 42/300 | Train loss: 3.221 | Validation loss: 3.043 | Accuracy: 0.230
# Epoch: 43/300 | Train loss: 3.202 | Validation loss: 3.009 | Accuracy: 0.241
# Epoch: 44/300 | Train loss: 3.200 | Validation loss: 2.982 | Accuracy: 0.242
# Epoch: 45/300 | Train loss: 3.186 | Validation loss: 2.993 | Accuracy: 0.239
# Epoch: 46/300 | Train loss: 3.182 | Validation loss: 3.014 | Accuracy: 0.233
# Epoch: 47/300 | Train loss: 3.158 | Validation loss: 2.967 | Accuracy: 0.248
# Epoch: 48/300 | Train loss: 3.155 | Validation loss: 2.987 | Accuracy: 0.241
# Epoch: 49/300 | Train loss: 3.147 | Validation loss: 2.945 | Accuracy: 0.247
# Epoch: 50/300 | Train loss: 3.125 | Validation loss: 2.931 | Accuracy: 0.251
# Epoch: 51/300 | Train loss: 3.122 | Validation loss: 2.976 | Accuracy: 0.246
# Epoch: 52/300 | Train loss: 3.106 | Validation loss: 2.892 | Accuracy: 0.253
# Epoch: 53/300 | Train loss: 3.098 | Validation loss: 2.873 | Accuracy: 0.267
# Epoch: 54/300 | Train loss: 3.091 | Validation loss: 2.969 | Accuracy: 0.250
# Epoch: 55/300 | Train loss: 3.086 | Validation loss: 2.869 | Accuracy: 0.265
# Epoch: 56/300 | Train loss: 3.073 | Validation loss: 2.841 | Accuracy: 0.270
# Epoch: 57/300 | Train loss: 3.066 | Validation loss: 2.895 | Accuracy: 0.262
# Epoch: 58/300 | Train loss: 3.068 | Validation loss: 2.855 | Accuracy: 0.268
# Epoch: 59/300 | Train loss: 3.058 | Validation loss: 2.862 | Accuracy: 0.264
# Epoch: 60/300 | Train loss: 3.048 | Validation loss: 2.810 | Accuracy: 0.269
# Epoch: 61/300 | Train loss: 3.052 | Validation loss: 2.918 | Accuracy: 0.254
# Epoch: 62/300 | Train loss: 3.037 | Validation loss: 2.821 | Accuracy: 0.277
# Epoch: 63/300 | Train loss: 3.040 | Validation loss: 2.795 | Accuracy: 0.276
# Epoch: 64/300 | Train loss: 3.031 | Validation loss: 2.814 | Accuracy: 0.277
# Epoch: 65/300 | Train loss: 3.031 | Validation loss: 2.796 | Accuracy: 0.281
# Epoch: 66/300 | Train loss: 3.026 | Validation loss: 2.805 | Accuracy: 0.272
# Epoch: 67/300 | Train loss: 3.016 | Validation loss: 2.831 | Accuracy: 0.266
# Epoch: 68/300 | Train loss: 3.016 | Validation loss: 2.799 | Accuracy: 0.272
# Epoch: 69/300 | Train loss: 3.014 | Validation loss: 2.800 | Accuracy: 0.281
# Epoch: 70/300 | Train loss: 3.002 | Validation loss: 2.792 | Accuracy: 0.280
# Epoch: 71/300 | Train loss: 3.006 | Validation loss: 2.814 | Accuracy: 0.279
# Epoch: 72/300 | Train loss: 2.991 | Validation loss: 2.788 | Accuracy: 0.276
# Epoch: 73/300 | Train loss: 2.994 | Validation loss: 2.826 | Accuracy: 0.275
# Epoch: 74/300 | Train loss: 2.993 | Validation loss: 2.780 | Accuracy: 0.281
# Epoch: 75/300 | Train loss: 2.989 | Validation loss: 2.802 | Accuracy: 0.283
# Epoch: 76/300 | Train loss: 2.979 | Validation loss: 2.753 | Accuracy: 0.289
# Epoch: 77/300 | Train loss: 2.989 | Validation loss: 2.804 | Accuracy: 0.274
# Epoch: 78/300 | Train loss: 2.974 | Validation loss: 2.812 | Accuracy: 0.275
# Epoch: 79/300 | Train loss: 2.976 | Validation loss: 2.766 | Accuracy: 0.284
# Epoch: 80/300 | Train loss: 2.978 | Validation loss: 2.777 | Accuracy: 0.288
# Epoch: 81/300 | Train loss: 2.964 | Validation loss: 2.752 | Accuracy: 0.294
# Epoch: 82/300 | Train loss: 2.966 | Validation loss: 2.778 | Accuracy: 0.283
# Epoch: 83/300 | Train loss: 2.972 | Validation loss: 2.740 | Accuracy: 0.285
# Epoch: 84/300 | Train loss: 2.966 | Validation loss: 2.788 | Accuracy: 0.284
# Epoch: 85/300 | Train loss: 2.964 | Validation loss: 2.796 | Accuracy: 0.281
# Epoch: 86/300 | Train loss: 2.965 | Validation loss: 2.746 | Accuracy: 0.287
# Epoch: 87/300 | Train loss: 2.954 | Validation loss: 2.725 | Accuracy: 0.294
# Epoch: 88/300 | Train loss: 2.950 | Validation loss: 2.752 | Accuracy: 0.293
# Epoch: 89/300 | Train loss: 2.949 | Validation loss: 2.719 | Accuracy: 0.294
# Epoch: 90/300 | Train loss: 2.946 | Validation loss: 2.782 | Accuracy: 0.284
# Epoch: 91/300 | Train loss: 2.941 | Validation loss: 2.720 | Accuracy: 0.297
# Epoch: 92/300 | Train loss: 2.949 | Validation loss: 2.801 | Accuracy: 0.282
# Epoch: 93/300 | Train loss: 2.948 | Validation loss: 2.742 | Accuracy: 0.290
# Epoch: 94/300 | Train loss: 2.940 | Validation loss: 2.766 | Accuracy: 0.280
# Epoch: 95/300 | Train loss: 2.941 | Validation loss: 2.704 | Accuracy: 0.293
# Epoch: 96/300 | Train loss: 2.946 | Validation loss: 2.749 | Accuracy: 0.296
# Epoch: 97/300 | Train loss: 2.926 | Validation loss: 2.727 | Accuracy: 0.301
# Epoch: 98/300 | Train loss: 2.939 | Validation loss: 2.730 | Accuracy: 0.293
# Epoch: 99/300 | Train loss: 2.930 | Validation loss: 2.797 | Accuracy: 0.292
# Epoch: 100/300 | Train loss: 2.928 | Validation loss: 2.720 | Accuracy: 0.298
# Epoch: 101/300 | Train loss: 2.800 | Validation loss: 2.623 | Accuracy: 0.316
# Epoch: 102/300 | Train loss: 2.772 | Validation loss: 2.591 | Accuracy: 0.322
# Epoch: 103/300 | Train loss: 2.769 | Validation loss: 2.596 | Accuracy: 0.318
# Epoch: 104/300 | Train loss: 2.736 | Validation loss: 2.588 | Accuracy: 0.319
# Epoch: 105/300 | Train loss: 2.735 | Validation loss: 2.583 | Accuracy: 0.320
# Epoch: 106/300 | Train loss: 2.732 | Validation loss: 2.615 | Accuracy: 0.318
# Epoch: 107/300 | Train loss: 2.730 | Validation loss: 2.568 | Accuracy: 0.324
# Epoch: 108/300 | Train loss: 2.730 | Validation loss: 2.590 | Accuracy: 0.328
# Epoch: 109/300 | Train loss: 2.717 | Validation loss: 2.596 | Accuracy: 0.324
# Epoch: 110/300 | Train loss: 2.715 | Validation loss: 2.570 | Accuracy: 0.322
# Epoch: 111/300 | Train loss: 2.701 | Validation loss: 2.604 | Accuracy: 0.325
# Epoch: 112/300 | Train loss: 2.708 | Validation loss: 2.554 | Accuracy: 0.328
# Epoch: 113/300 | Train loss: 2.705 | Validation loss: 2.555 | Accuracy: 0.329
# Epoch: 114/300 | Train loss: 2.698 | Validation loss: 2.571 | Accuracy: 0.330
# Epoch: 115/300 | Train loss: 2.707 | Validation loss: 2.561 | Accuracy: 0.330
# Epoch: 116/300 | Train loss: 2.692 | Validation loss: 2.582 | Accuracy: 0.324
# Epoch: 117/300 | Train loss: 2.693 | Validation loss: 2.549 | Accuracy: 0.329
# Epoch: 118/300 | Train loss: 2.691 | Validation loss: 2.561 | Accuracy: 0.339
# Epoch: 119/300 | Train loss: 2.684 | Validation loss: 2.563 | Accuracy: 0.328
# Epoch: 120/300 | Train loss: 2.683 | Validation loss: 2.560 | Accuracy: 0.332
# Epoch: 121/300 | Train loss: 2.693 | Validation loss: 2.549 | Accuracy: 0.328
# Epoch: 122/300 | Train loss: 2.685 | Validation loss: 2.582 | Accuracy: 0.331
# Epoch: 123/300 | Train loss: 2.683 | Validation loss: 2.570 | Accuracy: 0.328
# Epoch: 124/300 | Train loss: 2.678 | Validation loss: 2.554 | Accuracy: 0.330
# Epoch: 125/300 | Train loss: 2.676 | Validation loss: 2.582 | Accuracy: 0.328
# Epoch: 126/300 | Train loss: 2.692 | Validation loss: 2.576 | Accuracy: 0.327
# Epoch: 127/300 | Train loss: 2.682 | Validation loss: 2.528 | Accuracy: 0.340
# Epoch: 128/300 | Train loss: 2.679 | Validation loss: 2.531 | Accuracy: 0.340
# Epoch: 129/300 | Train loss: 2.677 | Validation loss: 2.568 | Accuracy: 0.328
# Epoch: 130/300 | Train loss: 2.673 | Validation loss: 2.554 | Accuracy: 0.329
# Epoch: 131/300 | Train loss: 2.672 | Validation loss: 2.541 | Accuracy: 0.330
# Epoch: 132/300 | Train loss: 2.668 | Validation loss: 2.572 | Accuracy: 0.328
# Epoch: 133/300 | Train loss: 2.673 | Validation loss: 2.568 | Accuracy: 0.334
# Epoch: 134/300 | Train loss: 2.671 | Validation loss: 2.535 | Accuracy: 0.335
# Epoch: 135/300 | Train loss: 2.662 | Validation loss: 2.574 | Accuracy: 0.332
# Epoch: 136/300 | Train loss: 2.674 | Validation loss: 2.555 | Accuracy: 0.337
# Epoch: 137/300 | Train loss: 2.665 | Validation loss: 2.533 | Accuracy: 0.335
# Epoch: 138/300 | Train loss: 2.667 | Validation loss: 2.562 | Accuracy: 0.335
# Epoch: 139/300 | Train loss: 2.670 | Validation loss: 2.543 | Accuracy: 0.331
# Epoch: 140/300 | Train loss: 2.659 | Validation loss: 2.528 | Accuracy: 0.342
# Epoch: 141/300 | Train loss: 2.672 | Validation loss: 2.553 | Accuracy: 0.333
# Epoch: 142/300 | Train loss: 2.667 | Validation loss: 2.542 | Accuracy: 0.338
# Epoch: 143/300 | Train loss: 2.669 | Validation loss: 2.546 | Accuracy: 0.332
# Epoch: 144/300 | Train loss: 2.661 | Validation loss: 2.541 | Accuracy: 0.336
# Epoch: 145/300 | Train loss: 2.661 | Validation loss: 2.546 | Accuracy: 0.330
# Epoch: 146/300 | Train loss: 2.658 | Validation loss: 2.546 | Accuracy: 0.335
# Epoch: 147/300 | Train loss: 2.662 | Validation loss: 2.533 | Accuracy: 0.339
# Epoch: 148/300 | Train loss: 2.662 | Validation loss: 2.530 | Accuracy: 0.336
# Epoch: 149/300 | Train loss: 2.662 | Validation loss: 2.543 | Accuracy: 0.336
# Epoch: 150/300 | Train loss: 2.663 | Validation loss: 2.526 | Accuracy: 0.347
# Epoch: 151/300 | Train loss: 2.657 | Validation loss: 2.566 | Accuracy: 0.333
# Epoch: 152/300 | Train loss: 2.653 | Validation loss: 2.542 | Accuracy: 0.335
# Epoch: 153/300 | Train loss: 2.661 | Validation loss: 2.563 | Accuracy: 0.334
# Epoch: 154/300 | Train loss: 2.650 | Validation loss: 2.528 | Accuracy: 0.341
# Epoch: 155/300 | Train loss: 2.645 | Validation loss: 2.513 | Accuracy: 0.343
# Epoch: 156/300 | Train loss: 2.650 | Validation loss: 2.547 | Accuracy: 0.343
# Epoch: 157/300 | Train loss: 2.647 | Validation loss: 2.555 | Accuracy: 0.333
# Epoch: 158/300 | Train loss: 2.653 | Validation loss: 2.538 | Accuracy: 0.337
# Epoch: 159/300 | Train loss: 2.647 | Validation loss: 2.535 | Accuracy: 0.342
# Epoch: 160/300 | Train loss: 2.643 | Validation loss: 2.537 | Accuracy: 0.334
# Epoch: 161/300 | Train loss: 2.648 | Validation loss: 2.546 | Accuracy: 0.332
# Epoch: 162/300 | Train loss: 2.645 | Validation loss: 2.533 | Accuracy: 0.339
# Epoch: 163/300 | Train loss: 2.647 | Validation loss: 2.526 | Accuracy: 0.334
# Epoch: 164/300 | Train loss: 2.643 | Validation loss: 2.535 | Accuracy: 0.342
# Epoch: 165/300 | Train loss: 2.640 | Validation loss: 2.511 | Accuracy: 0.342
# Epoch: 166/300 | Train loss: 2.644 | Validation loss: 2.539 | Accuracy: 0.337
# Epoch: 167/300 | Train loss: 2.646 | Validation loss: 2.512 | Accuracy: 0.348
# Epoch: 168/300 | Train loss: 2.637 | Validation loss: 2.520 | Accuracy: 0.343
# Epoch: 169/300 | Train loss: 2.643 | Validation loss: 2.529 | Accuracy: 0.339
# Epoch: 170/300 | Train loss: 2.634 | Validation loss: 2.541 | Accuracy: 0.338
# Epoch: 171/300 | Train loss: 2.643 | Validation loss: 2.523 | Accuracy: 0.341
# Epoch: 172/300 | Train loss: 2.630 | Validation loss: 2.536 | Accuracy: 0.343
# Epoch: 173/300 | Train loss: 2.641 | Validation loss: 2.529 | Accuracy: 0.344
# Epoch: 174/300 | Train loss: 2.636 | Validation loss: 2.531 | Accuracy: 0.337
# Epoch: 175/300 | Train loss: 2.637 | Validation loss: 2.550 | Accuracy: 0.336
# Epoch: 176/300 | Train loss: 2.625 | Validation loss: 2.522 | Accuracy: 0.345
# Epoch: 177/300 | Train loss: 2.629 | Validation loss: 2.513 | Accuracy: 0.340
# Epoch: 178/300 | Train loss: 2.632 | Validation loss: 2.531 | Accuracy: 0.343
# Epoch: 179/300 | Train loss: 2.632 | Validation loss: 2.542 | Accuracy: 0.339
# Epoch: 180/300 | Train loss: 2.632 | Validation loss: 2.526 | Accuracy: 0.344
# Epoch: 181/300 | Train loss: 2.632 | Validation loss: 2.509 | Accuracy: 0.344
# Epoch: 182/300 | Train loss: 2.638 | Validation loss: 2.502 | Accuracy: 0.348
# Epoch: 183/300 | Train loss: 2.630 | Validation loss: 2.525 | Accuracy: 0.341
# Epoch: 184/300 | Train loss: 2.617 | Validation loss: 2.502 | Accuracy: 0.348
# Epoch: 185/300 | Train loss: 2.616 | Validation loss: 2.518 | Accuracy: 0.346
# Epoch: 186/300 | Train loss: 2.633 | Validation loss: 2.524 | Accuracy: 0.341
# Epoch: 187/300 | Train loss: 2.628 | Validation loss: 2.515 | Accuracy: 0.345
# Epoch: 188/300 | Train loss: 2.621 | Validation loss: 2.550 | Accuracy: 0.334
# Epoch: 189/300 | Train loss: 2.629 | Validation loss: 2.502 | Accuracy: 0.342
# Epoch: 190/300 | Train loss: 2.620 | Validation loss: 2.508 | Accuracy: 0.348
# Epoch: 191/300 | Train loss: 2.627 | Validation loss: 2.506 | Accuracy: 0.348
# Epoch: 192/300 | Train loss: 2.626 | Validation loss: 2.487 | Accuracy: 0.345
# Epoch: 193/300 | Train loss: 2.620 | Validation loss: 2.507 | Accuracy: 0.353
# Epoch: 194/300 | Train loss: 2.614 | Validation loss: 2.525 | Accuracy: 0.341
# Epoch: 195/300 | Train loss: 2.615 | Validation loss: 2.492 | Accuracy: 0.352
# Epoch: 196/300 | Train loss: 2.630 | Validation loss: 2.511 | Accuracy: 0.346
# Epoch: 197/300 | Train loss: 2.625 | Validation loss: 2.547 | Accuracy: 0.333
# Epoch: 198/300 | Train loss: 2.625 | Validation loss: 2.519 | Accuracy: 0.346
# Epoch: 199/300 | Train loss: 2.608 | Validation loss: 2.511 | Accuracy: 0.346
# Epoch: 200/300 | Train loss: 2.621 | Validation loss: 2.505 | Accuracy: 0.347
# Epoch: 201/300 | Train loss: 2.546 | Validation loss: 2.476 | Accuracy: 0.347
# Epoch: 202/300 | Train loss: 2.502 | Validation loss: 2.452 | Accuracy: 0.366
# Epoch: 203/300 | Train loss: 2.502 | Validation loss: 2.430 | Accuracy: 0.360
# Epoch: 204/300 | Train loss: 2.502 | Validation loss: 2.439 | Accuracy: 0.364
# Epoch: 205/300 | Train loss: 2.496 | Validation loss: 2.419 | Accuracy: 0.370
# Epoch: 206/300 | Train loss: 2.483 | Validation loss: 2.450 | Accuracy: 0.356
# Epoch: 207/300 | Train loss: 2.472 | Validation loss: 2.429 | Accuracy: 0.365
# Epoch: 208/300 | Train loss: 2.480 | Validation loss: 2.434 | Accuracy: 0.362
# Epoch: 209/300 | Train loss: 2.482 | Validation loss: 2.442 | Accuracy: 0.363
# Epoch: 210/300 | Train loss: 2.483 | Validation loss: 2.427 | Accuracy: 0.366
# Epoch: 211/300 | Train loss: 2.467 | Validation loss: 2.440 | Accuracy: 0.367
# Epoch: 212/300 | Train loss: 2.462 | Validation loss: 2.433 | Accuracy: 0.364
# Epoch: 213/300 | Train loss: 2.465 | Validation loss: 2.437 | Accuracy: 0.362
# Epoch: 214/300 | Train loss: 2.473 | Validation loss: 2.417 | Accuracy: 0.366
# Epoch: 215/300 | Train loss: 2.467 | Validation loss: 2.446 | Accuracy: 0.358
# Epoch: 216/300 | Train loss: 2.463 | Validation loss: 2.431 | Accuracy: 0.363
# Epoch: 217/300 | Train loss: 2.457 | Validation loss: 2.430 | Accuracy: 0.364
# Epoch: 218/300 | Train loss: 2.459 | Validation loss: 2.418 | Accuracy: 0.361
# Epoch: 219/300 | Train loss: 2.464 | Validation loss: 2.422 | Accuracy: 0.369
# Epoch: 220/300 | Train loss: 2.450 | Validation loss: 2.444 | Accuracy: 0.365
# Epoch: 221/300 | Train loss: 2.452 | Validation loss: 2.426 | Accuracy: 0.362
# Epoch: 222/300 | Train loss: 2.457 | Validation loss: 2.433 | Accuracy: 0.367
# Epoch: 223/300 | Train loss: 2.445 | Validation loss: 2.436 | Accuracy: 0.365
# Epoch: 224/300 | Train loss: 2.452 | Validation loss: 2.427 | Accuracy: 0.369
# Epoch: 225/300 | Train loss: 2.441 | Validation loss: 2.407 | Accuracy: 0.372
# Epoch: 226/300 | Train loss: 2.449 | Validation loss: 2.431 | Accuracy: 0.361
# Epoch: 227/300 | Train loss: 2.435 | Validation loss: 2.436 | Accuracy: 0.363
# Epoch: 228/300 | Train loss: 2.449 | Validation loss: 2.437 | Accuracy: 0.367
# Epoch: 229/300 | Train loss: 2.453 | Validation loss: 2.433 | Accuracy: 0.362
# Epoch: 230/300 | Train loss: 2.454 | Validation loss: 2.422 | Accuracy: 0.367
# Epoch: 231/300 | Train loss: 2.442 | Validation loss: 2.413 | Accuracy: 0.370
# Epoch: 232/300 | Train loss: 2.445 | Validation loss: 2.427 | Accuracy: 0.367
# Epoch: 233/300 | Train loss: 2.449 | Validation loss: 2.428 | Accuracy: 0.368
# Epoch: 234/300 | Train loss: 2.443 | Validation loss: 2.428 | Accuracy: 0.367
# Epoch: 235/300 | Train loss: 2.447 | Validation loss: 2.443 | Accuracy: 0.369
# Epoch: 236/300 | Train loss: 2.461 | Validation loss: 2.424 | Accuracy: 0.365
# Epoch: 237/300 | Train loss: 2.445 | Validation loss: 2.429 | Accuracy: 0.370
# Epoch: 238/300 | Train loss: 2.442 | Validation loss: 2.420 | Accuracy: 0.368
# Epoch: 239/300 | Train loss: 2.434 | Validation loss: 2.417 | Accuracy: 0.367
# Epoch: 240/300 | Train loss: 2.447 | Validation loss: 2.434 | Accuracy: 0.364
# Epoch: 241/300 | Train loss: 2.444 | Validation loss: 2.418 | Accuracy: 0.368
# Epoch: 242/300 | Train loss: 2.438 | Validation loss: 2.420 | Accuracy: 0.365
# Epoch: 243/300 | Train loss: 2.436 | Validation loss: 2.435 | Accuracy: 0.366
# Epoch: 244/300 | Train loss: 2.437 | Validation loss: 2.411 | Accuracy: 0.367
# Epoch: 245/300 | Train loss: 2.428 | Validation loss: 2.423 | Accuracy: 0.372
# Epoch: 246/300 | Train loss: 2.441 | Validation loss: 2.423 | Accuracy: 0.374
# Epoch: 247/300 | Train loss: 2.435 | Validation loss: 2.433 | Accuracy: 0.368
# Epoch: 248/300 | Train loss: 2.449 | Validation loss: 2.439 | Accuracy: 0.362
# Epoch: 249/300 | Train loss: 2.444 | Validation loss: 2.433 | Accuracy: 0.365
# Epoch: 250/300 | Train loss: 2.437 | Validation loss: 2.427 | Accuracy: 0.367
# Epoch: 251/300 | Train loss: 2.442 | Validation loss: 2.424 | Accuracy: 0.372
# Epoch: 252/300 | Train loss: 2.437 | Validation loss: 2.422 | Accuracy: 0.369
# Epoch: 253/300 | Train loss: 2.443 | Validation loss: 2.430 | Accuracy: 0.370
# Epoch: 254/300 | Train loss: 2.443 | Validation loss: 2.426 | Accuracy: 0.366
# Epoch: 255/300 | Train loss: 2.431 | Validation loss: 2.429 | Accuracy: 0.375
# Epoch: 256/300 | Train loss: 2.439 | Validation loss: 2.421 | Accuracy: 0.367
# Epoch: 257/300 | Train loss: 2.431 | Validation loss: 2.432 | Accuracy: 0.367
# Epoch: 258/300 | Train loss: 2.435 | Validation loss: 2.419 | Accuracy: 0.371
# Epoch: 259/300 | Train loss: 2.426 | Validation loss: 2.433 | Accuracy: 0.365
# Epoch: 260/300 | Train loss: 2.432 | Validation loss: 2.444 | Accuracy: 0.367
# Epoch: 261/300 | Train loss: 2.433 | Validation loss: 2.419 | Accuracy: 0.372
# Epoch: 262/300 | Train loss: 2.429 | Validation loss: 2.419 | Accuracy: 0.367
# Epoch: 263/300 | Train loss: 2.428 | Validation loss: 2.410 | Accuracy: 0.372
# Epoch: 264/300 | Train loss: 2.430 | Validation loss: 2.414 | Accuracy: 0.368
# Epoch: 265/300 | Train loss: 2.430 | Validation loss: 2.435 | Accuracy: 0.371
# Epoch: 266/300 | Train loss: 2.438 | Validation loss: 2.405 | Accuracy: 0.372
# Epoch: 267/300 | Train loss: 2.435 | Validation loss: 2.383 | Accuracy: 0.377
# Epoch: 268/300 | Train loss: 2.428 | Validation loss: 2.407 | Accuracy: 0.370
# Epoch: 269/300 | Train loss: 2.424 | Validation loss: 2.396 | Accuracy: 0.374
# Epoch: 270/300 | Train loss: 2.429 | Validation loss: 2.409 | Accuracy: 0.371
# Epoch: 271/300 | Train loss: 2.438 | Validation loss: 2.412 | Accuracy: 0.371
# Epoch: 272/300 | Train loss: 2.429 | Validation loss: 2.431 | Accuracy: 0.368
# Epoch: 273/300 | Train loss: 2.425 | Validation loss: 2.394 | Accuracy: 0.374
# Epoch: 274/300 | Train loss: 2.429 | Validation loss: 2.408 | Accuracy: 0.376
# Epoch: 275/300 | Train loss: 2.431 | Validation loss: 2.416 | Accuracy: 0.367
# Epoch: 276/300 | Train loss: 2.420 | Validation loss: 2.415 | Accuracy: 0.372
# Epoch: 277/300 | Train loss: 2.424 | Validation loss: 2.422 | Accuracy: 0.371
# Epoch: 278/300 | Train loss: 2.421 | Validation loss: 2.407 | Accuracy: 0.374
# Epoch: 279/300 | Train loss: 2.425 | Validation loss: 2.414 | Accuracy: 0.376
# Epoch: 280/300 | Train loss: 2.428 | Validation loss: 2.418 | Accuracy: 0.380
# Epoch: 281/300 | Train loss: 2.431 | Validation loss: 2.382 | Accuracy: 0.382
# Epoch: 282/300 | Train loss: 2.420 | Validation loss: 2.406 | Accuracy: 0.374
# Epoch: 283/300 | Train loss: 2.419 | Validation loss: 2.423 | Accuracy: 0.369
# Epoch: 284/300 | Train loss: 2.424 | Validation loss: 2.407 | Accuracy: 0.372
# Epoch: 285/300 | Train loss: 2.422 | Validation loss: 2.407 | Accuracy: 0.375
# Epoch: 286/300 | Train loss: 2.419 | Validation loss: 2.433 | Accuracy: 0.372
# Epoch: 287/300 | Train loss: 2.433 | Validation loss: 2.416 | Accuracy: 0.373
# Epoch: 288/300 | Train loss: 2.418 | Validation loss: 2.386 | Accuracy: 0.375
# Epoch: 289/300 | Train loss: 2.423 | Validation loss: 2.405 | Accuracy: 0.375
# Epoch: 290/300 | Train loss: 2.426 | Validation loss: 2.412 | Accuracy: 0.377
# Epoch: 291/300 | Train loss: 2.418 | Validation loss: 2.437 | Accuracy: 0.372
# Epoch: 292/300 | Train loss: 2.427 | Validation loss: 2.411 | Accuracy: 0.371
# Epoch: 293/300 | Train loss: 2.420 | Validation loss: 2.407 | Accuracy: 0.368
# Epoch: 294/300 | Train loss: 2.416 | Validation loss: 2.408 | Accuracy: 0.376
# Epoch: 295/300 | Train loss: 2.414 | Validation loss: 2.417 | Accuracy: 0.377
# Epoch: 296/300 | Train loss: 2.421 | Validation loss: 2.415 | Accuracy: 0.376

# %% [markdown]
# # Metrics

# %%
fig, ax = plt.subplots(figsize=(6,6))

ax.plot(train_loss_history, label="Train Loss")
ax.plot(val_loss_history, label="Validation Loss")

ax.set_xlabel("epoch")
ax.set_ylabel("loss")
ax.set_title("Train Loss & Validation Loss")
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(accuracy_history, label="Accuracy")

ax.set_xlabel("epoch")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy")

plt.show()

# %%
# download the testset
testset = datasets.CIFAR100('.', download=True, train=False, transform=transform)

# loader for the testset
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=batch_size,
    shuffle=True
)

# %%
total = 0
total_corrects = 0
with torch.no_grad():

    for images, labels in testloader:

        images, labels = images.to(device), labels.to(device)

        logits = model.forward(images)

        probabilities = logits.softmax(dim=1)

        top_probs, top_classes = probabilities.topk(k=1, dim=1)
        corrects = (top_classes == labels.view(*top_classes.shape))
        corrects = int(torch.sum(corrects).cpu().numpy())
        total_corrects += corrects

        total += labels.size(0)

# %%
total_corrects / total * 100.0

# %% [markdown]
# ### 성능 개선
#
# 성능을 개선하기 위해 (Accuracy가 최소 50% 이상) 나오게 하기 위하여 여러 방법을 적용하였다.
#
# 1. Data Augumentation
# 2. CNN 모델을 더욱 복잡하고 설계
# 3. 옵티마이저 설정(L2 norm + optimizer: Adam + lr_scheduler)
# 4. 100 epochs를 수행 결과를 보면 overfitting이 발견되지 않았다.
#
# 결과적으로 더 많은 epochs를 수행하면 결국 50% 이상의 accuracy score를 얻을 수 있을 것이다.
