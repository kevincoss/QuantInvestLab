# %% [markdown]
# AIX30009 Fall 2024
#
# **_Copyright Notice_**
#
# This notebook is available for educational purposes. You may not use or distribute this notebook for commercial purposes. You may make copies of this notebook and use or distribute it for educational purposes as long as you cite the author as the source of the notebook.
#
# Jaeyoung Chun | School of Applied Artificial Intelligence | Handong Global University

# %% [markdown]
# # Fashion MNIST FIB (Fill in the Blank) Version

# %% [markdown]
# Replace ??? with proper values.

# %%
import torch
from torch import nn
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.5.1+cu121'

# %%
# %config InlineBackend.figure_format='retina'

# %%
# set the random seed
torch.manual_seed(316)

# %% [markdown]
# # Load Data

# %%
# convert to tensor
# data augumentation -> 성능 개선을 위해 추가한 방법
# normalize the data

transform = transforms.Compose(
    [
        transforms.RandomCrop(size=32, padding=4),  # CIFAR-10 기준
        transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),
        transforms.RandomHorizontalFlip(p=0.5),  # 좌우 뒤집기
        transforms.ToTensor(),
        transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
    ]
)

# %% [markdown]
# ## Download

# %%
# download the dataset
dataset = datasets.CIFAR100('.', download=True, train=True, transform=transform)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## Split

# %%
# split
len_trainset = int(len(dataset) * 0.8)
len_valset = len(dataset) - len_trainset

trainset, valset = torch.utils.data.random_split(dataset, [len_trainset, len_valset])

# %%
len(trainset)
# Out:
# 40000

# %%
len(valset)
# Out:
# 10000

# %% [markdown]
# ## Training Set

# %%
# loader for the training set
batch_size = 128
trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# ## Validation Set

# %%
# loader for the validatoin set
valloader = torch.utils.data.DataLoader(
    valset,
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# # Explore Data

# %%
idx_to_class = { v:k for k, v in trainset.dataset.class_to_idx.items() }
idx_to_class
# Out:
# {0: 'apple',
#  1: 'aquarium_fish',
#  2: 'baby',
#  3: 'bear',
#  4: 'beaver',
#  5: 'bed',
#  6: 'bee',
#  7: 'beetle',
#  8: 'bicycle',
#  9: 'bottle',
#  10: 'bowl',
#  11: 'boy',
#  12: 'bridge',
#  13: 'bus',
#  14: 'butterfly',
#  15: 'camel',
#  16: 'can',
#  17: 'castle',
#  18: 'caterpillar',
#  19: 'cattle',
#  20: 'chair',
#  21: 'chimpanzee',
#  22: 'clock',
#  23: 'cloud',
#  24: 'cockroach',
#  25: 'couch',
#  26: 'crab',
#  27: 'crocodile',
#  28: 'cup',
#  29: 'dinosaur',
#  30: 'dolphin',
#  31: 'elephant',
#  32: 'flatfish',
#  33: 'forest',
#  34: 'fox',
#  35: 'girl',
#  36: 'hamster',
#  37: 'house',
#  38: 'kangaroo',
#  39: 'keyboard',
#  40: 'lamp',
#  41: 'lawn_mower',
#  42: 'leopard',
#  43: 'lion',
#  44: 'lizard',
#  45: 'lobster',
#  46: 'man',
#  47: 'maple_tree',
#  48: 'motorcycle',
#  49: 'mountain',
#  50: 'mouse',
#  51: 'mushroom',
#  52: 'oak_tree',
#  53: 'orange',
#  54: 'orchid',
#  55: 'otter',
#  56: 'palm_tree',
#  57: 'pear',
#  58: 'pickup_truck',
#  59: 'pine_tree',
#  60: 'plain',
#  61: 'plate',
#  62: 'poppy',
#  63: 'porcupine',
#  64: 'possum',
#  65: 'rabbit',
#  66: 'raccoon',
#  67: 'ray',
#  68: 'road',
#  69: 'rocket',
#  70: 'rose',
#  71: 'sea',
#  72: 'seal',
#  73: 'shark',
#  74: 'shrew',
#  75: 'skunk',
#  76: 'skyscraper',
#  77: 'snail',
#  78: 'snake',
#  79: 'spider',
#  80: 'squirrel',
#  81: 'streetcar',
#  82: 'sunflower',
#  83: 'sweet_pepper',
#  84: 'table',
#  85: 'tank',
#  86: 'telephone',
#  87: 'television',
#  88: 'tiger',
#  89: 'tractor',
#  90: 'train',
#  91: 'trout',
#  92: 'tulip',
#  93: 'turtle',
#  94: 'wardrobe',
#  95: 'whale',
#  96: 'willow_tree',
#  97: 'wolf',
#  98: 'woman',
#  99: 'worm'}

# %%
# get a first batch
images, labels = next(iter(trainloader))

# %%
images.shape
# Out:
# torch.Size([128, 3, 32, 32])

# %%
fig, ax = plt.subplots(figsize=(3,3))

img_idx = 0
label = idx_to_class[int(labels[0])] # color img

ax.imshow(images[0][0])
ax.set_title(f"Label: {label}")

plt.show()

# %%
fig, ax = plt.subplots(ncols=5, nrows=3, figsize=(12,6))
ax = np.ravel(ax)

for index in range(15):
    ax[index].imshow(images[index][0]) # color img
    label = idx_to_class[int(labels[index])]
    ax[index].set_title(f"Label: {label}")
    ax[index].set_xticks([])
    ax[index].set_yticks([])

plt.show()

# %% [markdown]
# # Build Neural Network

# %%
from collections import OrderedDict
import torch.nn.functional as F

## 성능 개선을 위해 모델을 기존보다 더욱 복잡하게 설계

class Network(nn.Module):
    def __init__(self):
        super().__init__()

        self.feature_extraction = nn.Sequential(
            OrderedDict([
                ("conv1", nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)),
                ("bn1", nn.BatchNorm2d(64)),
                ("relu1", nn.ReLU()),
                ("pool1", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv2", nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)),
                ("bn2", nn.BatchNorm2d(128)),
                ("relu2", nn.ReLU()),
                ("pool2", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv3", nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)),
                ("bn3", nn.BatchNorm2d(256)),
                ("relu3", nn.ReLU()),
                ("pool3", nn.MaxPool2d(kernel_size=2, stride=2)),

                ("conv4", nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1)),
                ("bn4", nn.BatchNorm2d(512)),
                ("relu4", nn.ReLU()),
                ("pool4", nn.MaxPool2d(kernel_size=2, stride=2)),
            ])
        )

        self.classifier = nn.Sequential(
            OrderedDict([
                ("fc1", nn.Linear(512 * 2 * 2, 1024)),
                ("relu5", nn.ReLU()),
                ("dropout1", nn.Dropout(0.7)),

                ("fc2", nn.Linear(1024, 512)),
                ("relu6", nn.ReLU()),
                ("dropout2", nn.Dropout(0.7)),

                ("fc3", nn.Linear(512, 128)),
                ("relu7", nn.ReLU()),
                ("dropout3", nn.Dropout(0.7)),

                ("fc4", nn.Linear(128, 100))
            ])
        )

    def forward(self, x):
        out1 = self.feature_extraction(x)
        out2 = torch.flatten(out1, 1)
        out3 = self.classifier(out2)
        return out3

# 모델 인스턴스 생성 및 출력
model = Network()
print(model)
# Out:
# Network(
#   (feature_extraction): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU()
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU()
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (relu5): ReLU()
#     (dropout1): Dropout(p=0.7, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu6): ReLU()
#     (dropout2): Dropout(p=0.7, inplace=False)
#     (fc3): Linear(in_features=512, out_features=128, bias=True)
#     (relu7): ReLU()
#     (dropout3): Dropout(p=0.7, inplace=False)
#     (fc4): Linear(in_features=128, out_features=100, bias=True)
#   )
# )

# %%
total_params = 0
for name, param in model.named_parameters():
    print(name, param.shape, param.numel())
    total_params += param.numel()

print(f"Total number of parameters = {total_params}")
# Out:
# feature_extraction.conv1.weight torch.Size([64, 3, 3, 3]) 1728
# feature_extraction.conv1.bias torch.Size([64]) 64
# feature_extraction.bn1.weight torch.Size([64]) 64
# feature_extraction.bn1.bias torch.Size([64]) 64
# feature_extraction.conv2.weight torch.Size([128, 64, 3, 3]) 73728
# feature_extraction.conv2.bias torch.Size([128]) 128
# feature_extraction.bn2.weight torch.Size([128]) 128
# feature_extraction.bn2.bias torch.Size([128]) 128
# feature_extraction.conv3.weight torch.Size([256, 128, 3, 3]) 294912
# feature_extraction.conv3.bias torch.Size([256]) 256
# feature_extraction.bn3.weight torch.Size([256]) 256
# feature_extraction.bn3.bias torch.Size([256]) 256
# feature_extraction.conv4.weight torch.Size([512, 256, 3, 3]) 1179648
# feature_extraction.conv4.bias torch.Size([512]) 512
# feature_extraction.bn4.weight torch.Size([512]) 512
# feature_extraction.bn4.bias torch.Size([512]) 512
# classifier.fc1.weight torch.Size([1024, 2048]) 2097152
# classifier.fc1.bias torch.Size([1024]) 1024
# classifier.fc2.weight torch.Size([512, 1024]) 524288
# classifier.fc2.bias torch.Size([512]) 512
# classifier.fc3.weight torch.Size([128, 512]) 65536
# classifier.fc3.bias torch.Size([128]) 128
# classifier.fc4.weight torch.Size([100, 128]) 12800
# classifier.fc4.bias torch.Size([100]) 100
# Total number of parameters = 4254436

# %%
# from torchinfo import summary

# summary(model, input_size=(batch_size, 3, 32, 32), device="cpu")

# %% [markdown]
# # Training and Validation

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
if torch.cuda.is_available():
    print(torch.cuda.current_device())
# Out:
# 0

# %%
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA A100-SXM4-40GB

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model.to(device)
# Out:
# Network(
#   (feature_extraction): Sequential(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU()
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU()
#     (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#     (relu5): ReLU()
#     (dropout1): Dropout(p=0.7, inplace=False)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu6): ReLU()
#     (dropout2): Dropout(p=0.7, inplace=False)
#     (fc3): Linear(in_features=512, out_features=128, bias=True)
#     (relu7): ReLU()
#     (dropout3): Dropout(p=0.7, inplace=False)
#     (fc4): Linear(in_features=128, out_features=100, bias=True)
#   )
# )

# %%
import time

# %%
from torch import optim

# 성능 개선을 위해 L2 norm + optimizer: Adam + lr_scheduler 설정.

weight_decay = 0.001  # L2 정규화 적용
learning_rate = 0.001

# 옵티마이저 설정
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay, betas=(0.9, 0.999), eps=1e-08)

# learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

# define the loss
criterion = nn.CrossEntropyLoss()

# %%
start_time = time.time()

n_epochs = 300

train_loss_history = []
val_loss_history = []
accuracy_history = []

for epoch in range(n_epochs):

    train_loss = 0

    model.train()

    for images, labels in trainloader:

        images, labels = images.to(device), labels.to(device)

        # zero the gradients on each training pass
        optimizer.zero_grad()

        # make a forward pass through the network
        logits = model.forward(images)

        # use the network output to calculate the loss (output vs. ground truth)
        loss = criterion(logits, labels)

        # make a backward pass through the network to calculate the gradients (backpropagation)
        loss.backward()

        # update the weights
        optimizer.step()

        # keep track of the loss per epoch
        train_loss += loss.item()

    else:

        train_loss = train_loss / len(trainloader)
        train_loss_history.append(train_loss)

        val_loss = 0
        accuracy = 0

        with torch.no_grad():

            model.eval()

            for images, labels in valloader:

                images, labels = images.to(device), labels.to(device)

                logits = model.forward(images)

                loss = criterion(logits, labels)

                val_loss += loss.item()

                probabilities = logits.softmax(dim=1)

                top_probs, top_classes = probabilities.topk(k=1, dim=1)
                corrects = (top_classes == labels.view(*top_classes.shape))
                accuracy += torch.mean(corrects.type(torch.FloatTensor))

        val_loss = val_loss / len(valloader)
        val_loss_history.append(val_loss)

        accuracy = accuracy / len(valloader)
        accuracy_history.append(accuracy)

        metrics = f"Epoch: {epoch + 1:02}/{n_epochs:02}"
        metrics += " | "
        metrics += f"Train loss: {train_loss:.3f}"
        metrics += " | "
        metrics += f"Validation loss: {val_loss:.3f}"
        metrics += " | "
        metrics += f"Accuracy: {accuracy:.3f}"
        print(metrics)

        # 스케줄러 업데이트
        scheduler.step()  # 학습률 감소

print("Elapsed: {0:.2f} seconds".format(time.time() - start_time))
# Out:
# Epoch: 01/300 | Train loss: 4.607 | Validation loss: 4.542 | Accuracy: 0.015
# Epoch: 02/300 | Train loss: 4.483 | Validation loss: 4.413 | Accuracy: 0.025
# Epoch: 03/300 | Train loss: 4.408 | Validation loss: 4.425 | Accuracy: 0.022
# Epoch: 04/300 | Train loss: 4.366 | Validation loss: 4.366 | Accuracy: 0.030
# Epoch: 05/300 | Train loss: 4.336 | Validation loss: 4.306 | Accuracy: 0.026
# Epoch: 06/300 | Train loss: 4.289 | Validation loss: 4.228 | Accuracy: 0.034
# Epoch: 07/300 | Train loss: 4.242 | Validation loss: 4.144 | Accuracy: 0.041
# Epoch: 08/300 | Train loss: 4.171 | Validation loss: 4.058 | Accuracy: 0.051
# Epoch: 09/300 | Train loss: 4.092 | Validation loss: 3.979 | Accuracy: 0.063
# Epoch: 10/300 | Train loss: 4.029 | Validation loss: 3.907 | Accuracy: 0.079
# Epoch: 11/300 | Train loss: 3.946 | Validation loss: 3.774 | Accuracy: 0.095
# Epoch: 12/300 | Train loss: 3.854 | Validation loss: 3.701 | Accuracy: 0.100
# Epoch: 13/300 | Train loss: 3.792 | Validation loss: 3.643 | Accuracy: 0.114
# Epoch: 14/300 | Train loss: 3.740 | Validation loss: 3.610 | Accuracy: 0.121
# Epoch: 15/300 | Train loss: 3.699 | Validation loss: 3.492 | Accuracy: 0.129
# Epoch: 16/300 | Train loss: 3.644 | Validation loss: 3.432 | Accuracy: 0.146
# Epoch: 17/300 | Train loss: 3.589 | Validation loss: 3.418 | Accuracy: 0.151
# Epoch: 18/300 | Train loss: 3.549 | Validation loss: 3.384 | Accuracy: 0.144
# Epoch: 19/300 | Train loss: 3.521 | Validation loss: 3.389 | Accuracy: 0.153
# Epoch: 20/300 | Train loss: 3.486 | Validation loss: 3.344 | Accuracy: 0.162
# Epoch: 21/300 | Train loss: 3.431 | Validation loss: 3.226 | Accuracy: 0.184
# Epoch: 22/300 | Train loss: 3.399 | Validation loss: 3.233 | Accuracy: 0.178
# Epoch: 23/300 | Train loss: 3.385 | Validation loss: 3.186 | Accuracy: 0.182
# Epoch: 24/300 | Train loss: 3.341 | Validation loss: 3.164 | Accuracy: 0.191
# Epoch: 25/300 | Train loss: 3.308 | Validation loss: 3.069 | Accuracy: 0.200
# Epoch: 26/300 | Train loss: 3.290 | Validation loss: 3.119 | Accuracy: 0.198
# Epoch: 27/300 | Train loss: 3.259 | Validation loss: 3.034 | Accuracy: 0.219
# Epoch: 28/300 | Train loss: 3.239 | Validation loss: 2.984 | Accuracy: 0.218
# Epoch: 29/300 | Train loss: 3.210 | Validation loss: 2.982 | Accuracy: 0.228
# Epoch: 30/300 | Train loss: 3.203 | Validation loss: 2.943 | Accuracy: 0.234
# Epoch: 31/300 | Train loss: 3.182 | Validation loss: 2.959 | Accuracy: 0.236
# Epoch: 32/300 | Train loss: 3.158 | Validation loss: 2.974 | Accuracy: 0.230
# Epoch: 33/300 | Train loss: 3.134 | Validation loss: 2.883 | Accuracy: 0.247
# Epoch: 34/300 | Train loss: 3.119 | Validation loss: 2.926 | Accuracy: 0.237
# Epoch: 35/300 | Train loss: 3.105 | Validation loss: 2.894 | Accuracy: 0.247
# Epoch: 36/300 | Train loss: 3.095 | Validation loss: 2.878 | Accuracy: 0.247
# Epoch: 37/300 | Train loss: 3.074 | Validation loss: 2.880 | Accuracy: 0.250
# Epoch: 38/300 | Train loss: 3.064 | Validation loss: 2.836 | Accuracy: 0.263
# Epoch: 39/300 | Train loss: 3.033 | Validation loss: 2.855 | Accuracy: 0.256
# Epoch: 40/300 | Train loss: 3.035 | Validation loss: 2.815 | Accuracy: 0.263
# Epoch: 41/300 | Train loss: 3.029 | Validation loss: 2.804 | Accuracy: 0.261
# Epoch: 42/300 | Train loss: 3.007 | Validation loss: 2.751 | Accuracy: 0.275
# Epoch: 43/300 | Train loss: 2.989 | Validation loss: 2.770 | Accuracy: 0.275
# Epoch: 44/300 | Train loss: 2.983 | Validation loss: 2.764 | Accuracy: 0.271
# Epoch: 45/300 | Train loss: 2.968 | Validation loss: 2.757 | Accuracy: 0.280
# Epoch: 46/300 | Train loss: 2.966 | Validation loss: 2.815 | Accuracy: 0.265
# Epoch: 47/300 | Train loss: 2.947 | Validation loss: 2.719 | Accuracy: 0.283
# Epoch: 48/300 | Train loss: 2.941 | Validation loss: 2.809 | Accuracy: 0.273
# Epoch: 49/300 | Train loss: 2.933 | Validation loss: 2.683 | Accuracy: 0.299
# Epoch: 50/300 | Train loss: 2.916 | Validation loss: 2.689 | Accuracy: 0.289
# Epoch: 51/300 | Train loss: 2.811 | Validation loss: 2.577 | Accuracy: 0.307
# Epoch: 52/300 | Train loss: 2.785 | Validation loss: 2.582 | Accuracy: 0.311
# Epoch: 53/300 | Train loss: 2.768 | Validation loss: 2.576 | Accuracy: 0.309
# Epoch: 54/300 | Train loss: 2.765 | Validation loss: 2.556 | Accuracy: 0.319
# Epoch: 55/300 | Train loss: 2.751 | Validation loss: 2.552 | Accuracy: 0.320
# Epoch: 56/300 | Train loss: 2.735 | Validation loss: 2.514 | Accuracy: 0.327
# Epoch: 57/300 | Train loss: 2.730 | Validation loss: 2.534 | Accuracy: 0.315
# Epoch: 58/300 | Train loss: 2.724 | Validation loss: 2.524 | Accuracy: 0.324
# Epoch: 59/300 | Train loss: 2.710 | Validation loss: 2.501 | Accuracy: 0.332
# Epoch: 60/300 | Train loss: 2.707 | Validation loss: 2.536 | Accuracy: 0.328
# Epoch: 61/300 | Train loss: 2.694 | Validation loss: 2.504 | Accuracy: 0.339
# Epoch: 62/300 | Train loss: 2.688 | Validation loss: 2.497 | Accuracy: 0.332
# Epoch: 63/300 | Train loss: 2.689 | Validation loss: 2.504 | Accuracy: 0.339
# Epoch: 64/300 | Train loss: 2.687 | Validation loss: 2.520 | Accuracy: 0.334
# Epoch: 65/300 | Train loss: 2.683 | Validation loss: 2.473 | Accuracy: 0.344
# Epoch: 66/300 | Train loss: 2.676 | Validation loss: 2.501 | Accuracy: 0.334
# Epoch: 67/300 | Train loss: 2.672 | Validation loss: 2.473 | Accuracy: 0.345
# Epoch: 68/300 | Train loss: 2.662 | Validation loss: 2.492 | Accuracy: 0.337
# Epoch: 69/300 | Train loss: 2.663 | Validation loss: 2.466 | Accuracy: 0.347
# Epoch: 70/300 | Train loss: 2.658 | Validation loss: 2.465 | Accuracy: 0.345
# Epoch: 71/300 | Train loss: 2.658 | Validation loss: 2.460 | Accuracy: 0.352
# Epoch: 72/300 | Train loss: 2.653 | Validation loss: 2.468 | Accuracy: 0.349
# Epoch: 73/300 | Train loss: 2.652 | Validation loss: 2.491 | Accuracy: 0.344
# Epoch: 74/300 | Train loss: 2.627 | Validation loss: 2.499 | Accuracy: 0.344
# Epoch: 75/300 | Train loss: 2.642 | Validation loss: 2.451 | Accuracy: 0.353
# Epoch: 76/300 | Train loss: 2.638 | Validation loss: 2.462 | Accuracy: 0.351
# Epoch: 77/300 | Train loss: 2.627 | Validation loss: 2.427 | Accuracy: 0.354
# Epoch: 78/300 | Train loss: 2.614 | Validation loss: 2.430 | Accuracy: 0.355
# Epoch: 79/300 | Train loss: 2.620 | Validation loss: 2.425 | Accuracy: 0.353
# Epoch: 80/300 | Train loss: 2.622 | Validation loss: 2.475 | Accuracy: 0.347
# Epoch: 81/300 | Train loss: 2.614 | Validation loss: 2.489 | Accuracy: 0.335
# Epoch: 82/300 | Train loss: 2.606 | Validation loss: 2.426 | Accuracy: 0.354
# Epoch: 83/300 | Train loss: 2.611 | Validation loss: 2.437 | Accuracy: 0.355
# Epoch: 84/300 | Train loss: 2.588 | Validation loss: 2.428 | Accuracy: 0.355
# Epoch: 85/300 | Train loss: 2.602 | Validation loss: 2.411 | Accuracy: 0.356
# Epoch: 86/300 | Train loss: 2.589 | Validation loss: 2.401 | Accuracy: 0.363
# Epoch: 87/300 | Train loss: 2.596 | Validation loss: 2.402 | Accuracy: 0.354
# Epoch: 88/300 | Train loss: 2.596 | Validation loss: 2.437 | Accuracy: 0.362
# Epoch: 89/300 | Train loss: 2.594 | Validation loss: 2.415 | Accuracy: 0.355
# Epoch: 90/300 | Train loss: 2.589 | Validation loss: 2.425 | Accuracy: 0.360
# Epoch: 91/300 | Train loss: 2.578 | Validation loss: 2.398 | Accuracy: 0.370
# Epoch: 92/300 | Train loss: 2.586 | Validation loss: 2.420 | Accuracy: 0.363
# Epoch: 93/300 | Train loss: 2.579 | Validation loss: 2.388 | Accuracy: 0.366
# Epoch: 94/300 | Train loss: 2.574 | Validation loss: 2.392 | Accuracy: 0.361
# Epoch: 95/300 | Train loss: 2.574 | Validation loss: 2.388 | Accuracy: 0.368
# Epoch: 96/300 | Train loss: 2.586 | Validation loss: 2.388 | Accuracy: 0.373
# Epoch: 97/300 | Train loss: 2.570 | Validation loss: 2.357 | Accuracy: 0.362
# Epoch: 98/300 | Train loss: 2.566 | Validation loss: 2.382 | Accuracy: 0.367
# Epoch: 99/300 | Train loss: 2.556 | Validation loss: 2.416 | Accuracy: 0.361
# Epoch: 100/300 | Train loss: 2.567 | Validation loss: 2.378 | Accuracy: 0.372
# Epoch: 101/300 | Train loss: 2.496 | Validation loss: 2.299 | Accuracy: 0.385
# Epoch: 102/300 | Train loss: 2.464 | Validation loss: 2.282 | Accuracy: 0.391
# Epoch: 103/300 | Train loss: 2.457 | Validation loss: 2.313 | Accuracy: 0.389
# Epoch: 104/300 | Train loss: 2.459 | Validation loss: 2.290 | Accuracy: 0.391
# Epoch: 105/300 | Train loss: 2.454 | Validation loss: 2.309 | Accuracy: 0.388
# Epoch: 106/300 | Train loss: 2.445 | Validation loss: 2.267 | Accuracy: 0.387
# Epoch: 107/300 | Train loss: 2.442 | Validation loss: 2.271 | Accuracy: 0.394
# Epoch: 108/300 | Train loss: 2.439 | Validation loss: 2.254 | Accuracy: 0.400
# Epoch: 109/300 | Train loss: 2.434 | Validation loss: 2.271 | Accuracy: 0.393
# Epoch: 110/300 | Train loss: 2.437 | Validation loss: 2.262 | Accuracy: 0.396
# Epoch: 111/300 | Train loss: 2.436 | Validation loss: 2.286 | Accuracy: 0.388
# Epoch: 112/300 | Train loss: 2.424 | Validation loss: 2.266 | Accuracy: 0.388
# Epoch: 113/300 | Train loss: 2.420 | Validation loss: 2.258 | Accuracy: 0.391
# Epoch: 114/300 | Train loss: 2.426 | Validation loss: 2.263 | Accuracy: 0.392
# Epoch: 115/300 | Train loss: 2.413 | Validation loss: 2.292 | Accuracy: 0.392
# Epoch: 116/300 | Train loss: 2.417 | Validation loss: 2.251 | Accuracy: 0.394
# Epoch: 117/300 | Train loss: 2.420 | Validation loss: 2.254 | Accuracy: 0.401
# Epoch: 118/300 | Train loss: 2.412 | Validation loss: 2.261 | Accuracy: 0.396
# Epoch: 119/300 | Train loss: 2.413 | Validation loss: 2.250 | Accuracy: 0.396
# Epoch: 120/300 | Train loss: 2.409 | Validation loss: 2.282 | Accuracy: 0.392
# Epoch: 121/300 | Train loss: 2.416 | Validation loss: 2.223 | Accuracy: 0.402
# Epoch: 122/300 | Train loss: 2.415 | Validation loss: 2.250 | Accuracy: 0.396
# Epoch: 123/300 | Train loss: 2.405 | Validation loss: 2.243 | Accuracy: 0.395
# Epoch: 124/300 | Train loss: 2.397 | Validation loss: 2.233 | Accuracy: 0.400
# Epoch: 125/300 | Train loss: 2.400 | Validation loss: 2.269 | Accuracy: 0.387
# Epoch: 126/300 | Train loss: 2.393 | Validation loss: 2.236 | Accuracy: 0.397
# Epoch: 127/300 | Train loss: 2.395 | Validation loss: 2.247 | Accuracy: 0.391
# Epoch: 128/300 | Train loss: 2.398 | Validation loss: 2.266 | Accuracy: 0.398
# Epoch: 129/300 | Train loss: 2.394 | Validation loss: 2.230 | Accuracy: 0.402
# Epoch: 130/300 | Train loss: 2.394 | Validation loss: 2.244 | Accuracy: 0.403
# Epoch: 131/300 | Train loss: 2.388 | Validation loss: 2.249 | Accuracy: 0.403
# Epoch: 132/300 | Train loss: 2.387 | Validation loss: 2.229 | Accuracy: 0.405
# Epoch: 133/300 | Train loss: 2.383 | Validation loss: 2.220 | Accuracy: 0.406
# Epoch: 134/300 | Train loss: 2.381 | Validation loss: 2.222 | Accuracy: 0.406
# Epoch: 135/300 | Train loss: 2.379 | Validation loss: 2.232 | Accuracy: 0.396
# Epoch: 136/300 | Train loss: 2.385 | Validation loss: 2.247 | Accuracy: 0.397
# Epoch: 137/300 | Train loss: 2.377 | Validation loss: 2.270 | Accuracy: 0.390
# Epoch: 138/300 | Train loss: 2.382 | Validation loss: 2.229 | Accuracy: 0.407
# Epoch: 139/300 | Train loss: 2.375 | Validation loss: 2.228 | Accuracy: 0.408
# Epoch: 140/300 | Train loss: 2.378 | Validation loss: 2.222 | Accuracy: 0.408
# Epoch: 141/300 | Train loss: 2.383 | Validation loss: 2.286 | Accuracy: 0.396
# Epoch: 142/300 | Train loss: 2.372 | Validation loss: 2.223 | Accuracy: 0.402
# Epoch: 143/300 | Train loss: 2.379 | Validation loss: 2.245 | Accuracy: 0.401
# Epoch: 144/300 | Train loss: 2.372 | Validation loss: 2.285 | Accuracy: 0.389
# Epoch: 145/300 | Train loss: 2.369 | Validation loss: 2.250 | Accuracy: 0.401
# Epoch: 146/300 | Train loss: 2.378 | Validation loss: 2.226 | Accuracy: 0.400
# Epoch: 147/300 | Train loss: 2.370 | Validation loss: 2.214 | Accuracy: 0.407
# Epoch: 148/300 | Train loss: 2.371 | Validation loss: 2.215 | Accuracy: 0.405
# Epoch: 149/300 | Train loss: 2.371 | Validation loss: 2.247 | Accuracy: 0.403
# Epoch: 150/300 | Train loss: 2.372 | Validation loss: 2.218 | Accuracy: 0.409
# Epoch: 151/300 | Train loss: 2.338 | Validation loss: 2.202 | Accuracy: 0.418
# Epoch: 152/300 | Train loss: 2.320 | Validation loss: 2.197 | Accuracy: 0.417
# Epoch: 153/300 | Train loss: 2.308 | Validation loss: 2.168 | Accuracy: 0.422
# Epoch: 154/300 | Train loss: 2.309 | Validation loss: 2.179 | Accuracy: 0.415
# Epoch: 155/300 | Train loss: 2.304 | Validation loss: 2.186 | Accuracy: 0.416
# Epoch: 156/300 | Train loss: 2.300 | Validation loss: 2.173 | Accuracy: 0.416
# Epoch: 157/300 | Train loss: 2.300 | Validation loss: 2.181 | Accuracy: 0.413
# Epoch: 158/300 | Train loss: 2.299 | Validation loss: 2.175 | Accuracy: 0.419
# Epoch: 159/300 | Train loss: 2.291 | Validation loss: 2.183 | Accuracy: 0.419
# Epoch: 160/300 | Train loss: 2.296 | Validation loss: 2.179 | Accuracy: 0.420
# Epoch: 161/300 | Train loss: 2.286 | Validation loss: 2.198 | Accuracy: 0.414
# Epoch: 162/300 | Train loss: 2.291 | Validation loss: 2.171 | Accuracy: 0.419
# Epoch: 163/300 | Train loss: 2.292 | Validation loss: 2.163 | Accuracy: 0.419
# Epoch: 164/300 | Train loss: 2.297 | Validation loss: 2.168 | Accuracy: 0.418
# Epoch: 165/300 | Train loss: 2.280 | Validation loss: 2.163 | Accuracy: 0.421
# Epoch: 166/300 | Train loss: 2.277 | Validation loss: 2.160 | Accuracy: 0.416
# Epoch: 167/300 | Train loss: 2.285 | Validation loss: 2.167 | Accuracy: 0.419
# Epoch: 168/300 | Train loss: 2.289 | Validation loss: 2.171 | Accuracy: 0.417
# Epoch: 169/300 | Train loss: 2.282 | Validation loss: 2.166 | Accuracy: 0.422
# Epoch: 170/300 | Train loss: 2.289 | Validation loss: 2.157 | Accuracy: 0.420
# Epoch: 171/300 | Train loss: 2.277 | Validation loss: 2.140 | Accuracy: 0.429
# Epoch: 172/300 | Train loss: 2.282 | Validation loss: 2.166 | Accuracy: 0.416
# Epoch: 173/300 | Train loss: 2.266 | Validation loss: 2.153 | Accuracy: 0.424
# Epoch: 174/300 | Train loss: 2.285 | Validation loss: 2.171 | Accuracy: 0.413
# Epoch: 175/300 | Train loss: 2.282 | Validation loss: 2.155 | Accuracy: 0.426
# Epoch: 176/300 | Train loss: 2.278 | Validation loss: 2.175 | Accuracy: 0.420
# Epoch: 177/300 | Train loss: 2.270 | Validation loss: 2.145 | Accuracy: 0.424
# Epoch: 178/300 | Train loss: 2.268 | Validation loss: 2.150 | Accuracy: 0.421
# Epoch: 179/300 | Train loss: 2.265 | Validation loss: 2.161 | Accuracy: 0.423
# Epoch: 180/300 | Train loss: 2.268 | Validation loss: 2.184 | Accuracy: 0.418
# Epoch: 181/300 | Train loss: 2.262 | Validation loss: 2.162 | Accuracy: 0.423
# Epoch: 182/300 | Train loss: 2.275 | Validation loss: 2.152 | Accuracy: 0.428
# Epoch: 183/300 | Train loss: 2.282 | Validation loss: 2.172 | Accuracy: 0.419
# Epoch: 184/300 | Train loss: 2.265 | Validation loss: 2.144 | Accuracy: 0.426
# Epoch: 185/300 | Train loss: 2.274 | Validation loss: 2.150 | Accuracy: 0.421
# Epoch: 186/300 | Train loss: 2.265 | Validation loss: 2.139 | Accuracy: 0.423
# Epoch: 187/300 | Train loss: 2.264 | Validation loss: 2.161 | Accuracy: 0.425
# Epoch: 188/300 | Train loss: 2.266 | Validation loss: 2.173 | Accuracy: 0.421
# Epoch: 189/300 | Train loss: 2.269 | Validation loss: 2.140 | Accuracy: 0.425
# Epoch: 190/300 | Train loss: 2.266 | Validation loss: 2.135 | Accuracy: 0.430
# Epoch: 191/300 | Train loss: 2.267 | Validation loss: 2.140 | Accuracy: 0.432
# Epoch: 192/300 | Train loss: 2.244 | Validation loss: 2.150 | Accuracy: 0.420
# Epoch: 193/300 | Train loss: 2.251 | Validation loss: 2.165 | Accuracy: 0.418
# Epoch: 194/300 | Train loss: 2.264 | Validation loss: 2.152 | Accuracy: 0.424
# Epoch: 195/300 | Train loss: 2.258 | Validation loss: 2.156 | Accuracy: 0.427
# Epoch: 196/300 | Train loss: 2.256 | Validation loss: 2.133 | Accuracy: 0.430
# Epoch: 197/300 | Train loss: 2.272 | Validation loss: 2.138 | Accuracy: 0.429
# Epoch: 198/300 | Train loss: 2.254 | Validation loss: 2.125 | Accuracy: 0.425
# Epoch: 199/300 | Train loss: 2.253 | Validation loss: 2.142 | Accuracy: 0.426
# Epoch: 200/300 | Train loss: 2.259 | Validation loss: 2.145 | Accuracy: 0.425
# Epoch: 201/300 | Train loss: 2.236 | Validation loss: 2.144 | Accuracy: 0.431
# Epoch: 202/300 | Train loss: 2.232 | Validation loss: 2.137 | Accuracy: 0.429
# Epoch: 203/300 | Train loss: 2.222 | Validation loss: 2.147 | Accuracy: 0.424
# Epoch: 204/300 | Train loss: 2.221 | Validation loss: 2.106 | Accuracy: 0.433
# Epoch: 205/300 | Train loss: 2.218 | Validation loss: 2.135 | Accuracy: 0.426
# Epoch: 206/300 | Train loss: 2.224 | Validation loss: 2.118 | Accuracy: 0.434
# Epoch: 207/300 | Train loss: 2.214 | Validation loss: 2.122 | Accuracy: 0.428
# Epoch: 208/300 | Train loss: 2.218 | Validation loss: 2.117 | Accuracy: 0.435
# Epoch: 209/300 | Train loss: 2.206 | Validation loss: 2.123 | Accuracy: 0.434
# Epoch: 210/300 | Train loss: 2.219 | Validation loss: 2.117 | Accuracy: 0.428
# Epoch: 211/300 | Train loss: 2.211 | Validation loss: 2.105 | Accuracy: 0.430
# Epoch: 212/300 | Train loss: 2.215 | Validation loss: 2.117 | Accuracy: 0.432
# Epoch: 213/300 | Train loss: 2.217 | Validation loss: 2.134 | Accuracy: 0.428
# Epoch: 214/300 | Train loss: 2.208 | Validation loss: 2.121 | Accuracy: 0.429
# Epoch: 215/300 | Train loss: 2.212 | Validation loss: 2.117 | Accuracy: 0.431
# Epoch: 216/300 | Train loss: 2.205 | Validation loss: 2.123 | Accuracy: 0.427
# Epoch: 217/300 | Train loss: 2.215 | Validation loss: 2.120 | Accuracy: 0.434
# Epoch: 218/300 | Train loss: 2.206 | Validation loss: 2.122 | Accuracy: 0.436
# Epoch: 219/300 | Train loss: 2.202 | Validation loss: 2.109 | Accuracy: 0.435
# Epoch: 220/300 | Train loss: 2.212 | Validation loss: 2.104 | Accuracy: 0.437
# Epoch: 221/300 | Train loss: 2.213 | Validation loss: 2.118 | Accuracy: 0.426
# Epoch: 222/300 | Train loss: 2.207 | Validation loss: 2.122 | Accuracy: 0.428
# Epoch: 223/300 | Train loss: 2.211 | Validation loss: 2.113 | Accuracy: 0.431
# Epoch: 224/300 | Train loss: 2.205 | Validation loss: 2.101 | Accuracy: 0.431
# Epoch: 225/300 | Train loss: 2.211 | Validation loss: 2.119 | Accuracy: 0.437
# Epoch: 226/300 | Train loss: 2.207 | Validation loss: 2.116 | Accuracy: 0.434
# Epoch: 227/300 | Train loss: 2.207 | Validation loss: 2.133 | Accuracy: 0.432
# Epoch: 228/300 | Train loss: 2.216 | Validation loss: 2.114 | Accuracy: 0.433
# Epoch: 229/300 | Train loss: 2.192 | Validation loss: 2.098 | Accuracy: 0.438
# Epoch: 230/300 | Train loss: 2.196 | Validation loss: 2.106 | Accuracy: 0.437
# Epoch: 231/300 | Train loss: 2.199 | Validation loss: 2.121 | Accuracy: 0.434
# Epoch: 232/300 | Train loss: 2.199 | Validation loss: 2.116 | Accuracy: 0.434
# Epoch: 233/300 | Train loss: 2.208 | Validation loss: 2.100 | Accuracy: 0.434
# Epoch: 234/300 | Train loss: 2.201 | Validation loss: 2.119 | Accuracy: 0.430
# Epoch: 235/300 | Train loss: 2.200 | Validation loss: 2.106 | Accuracy: 0.435
# Epoch: 236/300 | Train loss: 2.204 | Validation loss: 2.109 | Accuracy: 0.434
# Epoch: 237/300 | Train loss: 2.193 | Validation loss: 2.101 | Accuracy: 0.437
# Epoch: 238/300 | Train loss: 2.190 | Validation loss: 2.105 | Accuracy: 0.435
# Epoch: 239/300 | Train loss: 2.198 | Validation loss: 2.101 | Accuracy: 0.436
# Epoch: 240/300 | Train loss: 2.198 | Validation loss: 2.121 | Accuracy: 0.430
# Epoch: 241/300 | Train loss: 2.191 | Validation loss: 2.122 | Accuracy: 0.437
# Epoch: 242/300 | Train loss: 2.191 | Validation loss: 2.136 | Accuracy: 0.427
# Epoch: 243/300 | Train loss: 2.200 | Validation loss: 2.127 | Accuracy: 0.436
# Epoch: 244/300 | Train loss: 2.191 | Validation loss: 2.115 | Accuracy: 0.434
# Epoch: 245/300 | Train loss: 2.199 | Validation loss: 2.105 | Accuracy: 0.436
# Epoch: 246/300 | Train loss: 2.183 | Validation loss: 2.099 | Accuracy: 0.436
# Epoch: 247/300 | Train loss: 2.187 | Validation loss: 2.113 | Accuracy: 0.435
# Epoch: 248/300 | Train loss: 2.193 | Validation loss: 2.102 | Accuracy: 0.433
# Epoch: 249/300 | Train loss: 2.189 | Validation loss: 2.107 | Accuracy: 0.441
# Epoch: 250/300 | Train loss: 2.195 | Validation loss: 2.097 | Accuracy: 0.433
# Epoch: 251/300 | Train loss: 2.167 | Validation loss: 2.101 | Accuracy: 0.440
# Epoch: 252/300 | Train loss: 2.187 | Validation loss: 2.098 | Accuracy: 0.436
# Epoch: 253/300 | Train loss: 2.176 | Validation loss: 2.075 | Accuracy: 0.448
# Epoch: 254/300 | Train loss: 2.185 | Validation loss: 2.091 | Accuracy: 0.438
# Epoch: 255/300 | Train loss: 2.184 | Validation loss: 2.104 | Accuracy: 0.439
# Epoch: 256/300 | Train loss: 2.176 | Validation loss: 2.093 | Accuracy: 0.439
# Epoch: 257/300 | Train loss: 2.171 | Validation loss: 2.102 | Accuracy: 0.436
# Epoch: 258/300 | Train loss: 2.175 | Validation loss: 2.108 | Accuracy: 0.431
# Epoch: 259/300 | Train loss: 2.175 | Validation loss: 2.090 | Accuracy: 0.434
# Epoch: 260/300 | Train loss: 2.183 | Validation loss: 2.089 | Accuracy: 0.439
# Epoch: 261/300 | Train loss: 2.174 | Validation loss: 2.089 | Accuracy: 0.440
# Epoch: 262/300 | Train loss: 2.177 | Validation loss: 2.075 | Accuracy: 0.444
# Epoch: 263/300 | Train loss: 2.174 | Validation loss: 2.086 | Accuracy: 0.438
# Epoch: 264/300 | Train loss: 2.178 | Validation loss: 2.096 | Accuracy: 0.437
# Epoch: 265/300 | Train loss: 2.175 | Validation loss: 2.090 | Accuracy: 0.440
# Epoch: 266/300 | Train loss: 2.172 | Validation loss: 2.088 | Accuracy: 0.436
# Epoch: 267/300 | Train loss: 2.173 | Validation loss: 2.104 | Accuracy: 0.437
# Epoch: 268/300 | Train loss: 2.175 | Validation loss: 2.092 | Accuracy: 0.441
# Epoch: 269/300 | Train loss: 2.170 | Validation loss: 2.099 | Accuracy: 0.438
# Epoch: 270/300 | Train loss: 2.162 | Validation loss: 2.078 | Accuracy: 0.445
# Epoch: 271/300 | Train loss: 2.172 | Validation loss: 2.107 | Accuracy: 0.439
# Epoch: 272/300 | Train loss: 2.172 | Validation loss: 2.102 | Accuracy: 0.436
# Epoch: 273/300 | Train loss: 2.175 | Validation loss: 2.096 | Accuracy: 0.438
# Epoch: 274/300 | Train loss: 2.168 | Validation loss: 2.088 | Accuracy: 0.440
# Epoch: 275/300 | Train loss: 2.159 | Validation loss: 2.105 | Accuracy: 0.440
# Epoch: 276/300 | Train loss: 2.169 | Validation loss: 2.074 | Accuracy: 0.445
# Epoch: 277/300 | Train loss: 2.168 | Validation loss: 2.085 | Accuracy: 0.440
# Epoch: 278/300 | Train loss: 2.163 | Validation loss: 2.104 | Accuracy: 0.431
# Epoch: 279/300 | Train loss: 2.170 | Validation loss: 2.108 | Accuracy: 0.435
# Epoch: 280/300 | Train loss: 2.171 | Validation loss: 2.094 | Accuracy: 0.442
# Epoch: 281/300 | Train loss: 2.159 | Validation loss: 2.086 | Accuracy: 0.438
# Epoch: 282/300 | Train loss: 2.164 | Validation loss: 2.099 | Accuracy: 0.442
# Epoch: 283/300 | Train loss: 2.170 | Validation loss: 2.112 | Accuracy: 0.437
# Epoch: 284/300 | Train loss: 2.166 | Validation loss: 2.075 | Accuracy: 0.440
# Epoch: 285/300 | Train loss: 2.164 | Validation loss: 2.101 | Accuracy: 0.433
# Epoch: 286/300 | Train loss: 2.164 | Validation loss: 2.086 | Accuracy: 0.442
# Epoch: 287/300 | Train loss: 2.162 | Validation loss: 2.108 | Accuracy: 0.438
# Epoch: 288/300 | Train loss: 2.164 | Validation loss: 2.087 | Accuracy: 0.445
# Epoch: 289/300 | Train loss: 2.177 | Validation loss: 2.084 | Accuracy: 0.437
# Epoch: 290/300 | Train loss: 2.168 | Validation loss: 2.088 | Accuracy: 0.440
# Epoch: 291/300 | Train loss: 2.171 | Validation loss: 2.108 | Accuracy: 0.429
# Epoch: 292/300 | Train loss: 2.161 | Validation loss: 2.083 | Accuracy: 0.442
# Epoch: 293/300 | Train loss: 2.164 | Validation loss: 2.094 | Accuracy: 0.440
# Epoch: 294/300 | Train loss: 2.163 | Validation loss: 2.066 | Accuracy: 0.446
# Epoch: 295/300 | Train loss: 2.165 | Validation loss: 2.095 | Accuracy: 0.434
# Epoch: 296/300 | Train loss: 2.166 | Validation loss: 2.078 | Accuracy: 0.437
# Epoch: 297/300 | Train loss: 2.164 | Validation loss: 2.066 | Accuracy: 0.445
# Epoch: 298/300 | Train loss: 2.163 | Validation loss: 2.088 | Accuracy: 0.439
# Epoch: 299/300 | Train loss: 2.168 | Validation loss: 2.096 | Accuracy: 0.443
# Epoch: 300/300 | Train loss: 2.160 | Validation loss: 2.077 | Accuracy: 0.443
# Elapsed: 14926.62 seconds

# %% [markdown]
# # Metrics

# %%
fig, ax = plt.subplots(figsize=(6,6))

ax.plot(train_loss_history, label="Train Loss")
ax.plot(val_loss_history, label="Validation Loss")

ax.set_xlabel("epoch")
ax.set_ylabel("loss")
ax.set_title("Train Loss & Validation Loss")
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(accuracy_history, label="Accuracy")

ax.set_xlabel("epoch")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy")

plt.show()

# %%
# download the testset
testset = datasets.CIFAR100('.', download=True, train=False, transform=transform)

# loader for the testset
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=batch_size,
    shuffle=True
)
# Out:
# Files already downloaded and verified

# %%
total = 0
total_corrects = 0
with torch.no_grad():

    for images, labels in testloader:

        images, labels = images.to(device), labels.to(device)

        logits = model.forward(images)

        probabilities = logits.softmax(dim=1)

        top_probs, top_classes = probabilities.topk(k=1, dim=1)
        corrects = (top_classes == labels.view(*top_classes.shape))
        corrects = int(torch.sum(corrects).cpu().numpy())
        total_corrects += corrects

        total += labels.size(0)

# %%
total_corrects / total * 100.0
# Out:
# 45.269999999999996

# %% [markdown]
# ### 성능 개선
#
# 성능을 개선하기 위해 (Accuracy가 최소 50% 이상) 나오게 하기 위하여 여러 방법을 적용하였다.
#
# 1. Data Augumentation
# 2. CNN 모델을 더욱 복잡하고 설계
# 3. 옵티마이저 설정(L2 norm + optimizer: Adam + lr_scheduler)
# 4. 100 epochs를 수행 결과를 보면 overfitting이 발견되지 않았다.
#
# 결과적으로 더 많은 epochs를 수행하면 결국 50% 이상의 accuracy score를 얻을 수 있을 것이다.
